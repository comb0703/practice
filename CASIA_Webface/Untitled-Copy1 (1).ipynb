# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os
import time
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt 
import numpy as np 
import torch.nn.functional as F
from torch.nn import Parameter
import numpy as np

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:1

# %%
# path

trainset_path = '/dataset/casia_webface_imgs_112_112'
testset_path = '/dataset/LFW/lfw'

# training dataset preprocessing

trainset_preprocess = transforms.Compose([
    transforms.Resize((112,112)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# test dataset preprocessing

testset_preprocess = transforms.Compose([
    transforms.ToTensor()
])

trainset = ImageFolder(trainset_path, transform=trainset_preprocess)
testset = ImageFolder(trainset_path, transform=testset_preprocess)
train_loader = DataLoader(trainset, batch_size=64, shuffle=True, num_workers=1)
test_loader = DataLoader(testset, batch_size=64, shuffle=True, num_workers=1)

# %%
# training set

TRAIN_NUM_CLASS = len(trainset.classes)
TRAIN_NUM_DATA = len(trainset)

# test set

TEST_NUM_CLASS = len(testset.classes)
TEST_NUM_DATA = len(testset)

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) 

        
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) 

        self.shortcut = nn.Sequential() # identity
        if stride != 1: 
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = F.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes):
        super(ResNet, self).__init__()
        self.in_planes = 32
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(32)
        self.prelu = nn.PReLU(32)
        self.layer1 = self._make_layer(block, 32, num_blocks[0], stride=1) #32
        self.layer2 = self._make_layer(block, 64, num_blocks[1], stride=2) #16
        self.layer3 = self._make_layer(block, 128, num_blocks[2], stride=2) #8
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(p=0.4, inplace=True)

        #self.weight = Parameter(torch.FloatTensor(num_classes, 64))
        #nn.init.xavier_uniform_(self.weight)

        self.linear = nn.Linear(128, num_classes, bias=False) 
        #with torch.no_grad():
        #  self.linear.weight.div_(torch.norm(self.linear.weight, dim=1, keepdim=True)) #normalize weights 


    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)

    def forward(self, x, label):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.prelu(out)
        out = F.relu(out)

        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.dropout(out)

        out = self.linear(out) 
        return out

# %%
def resnet38():
    return ResNet(BasicBlock, [6, 6, 6], num_classes=TRAIN_NUM_CLASS)

# %%
net = resnet38()
net = net.to(device)

learning_rate = 0.1
file_name = 'resnet38_softmax.pth' ###

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate)
#momentum=0.9, weight_decay=0.0002

train_losses = []
train_accuracy = [] 
test_losses = []
test_accuracy = []

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        #optimizer.zero_grad()

        outputs = net(inputs, targets)

        lamda = 0.1

        loss = criterion(outputs, targets)
        optimizer.zero_grad()
        loss.backward()

        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)

        total += targets.size(0)
        current_correct = predicted.eq(targets).sum().item()
        correct += current_correct
        
        if batch_idx % 500 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current batch average train accuracy:', current_correct / targets.size(0))
            print('Current batch average train loss:', loss.item() / targets.size(0))
            
            train_losses.append(loss.item() / targets.size(0))
            train_accuracy.append(current_correct / targets.size(0))

    print('\nTotal average train accuarcy:', correct / total)
    print('Total average train loss:', train_loss / total)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)
        #
        zero_targets = torch.zeros(targets.size(0)).to(device)

        outputs, _ = net(inputs, zero_targets)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTotal average test accuarcy:', correct / total)
    print('Total average test loss:', loss / total)

    test_losses.append(loss / total)
    test_accuracy.append(correct / total)

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    #if epoch >= 50:
    if epoch >= 50:
        lr /= 10
    #if epoch >= 100:
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

start_time = time.time()

# %%
for epoch in range(0, 120):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    #test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.13422676920890808
#
# Current batch: 500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.1352466642856598
#
# Current batch: 1000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.1325031965970993
#
# Current batch: 1500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.12945035099983215
#
# Current batch: 2000
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.1304677128791809
#
# Current batch: 2500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.13039493560791016
#
# Current batch: 3000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.12909387052059174
#
# Current batch: 3500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.12371207773685455
#
# Current batch: 4000
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.13156747817993164
#
# Current batch: 4500
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.12854988873004913
#
# Current batch: 5000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.13084007799625397
#
# Current batch: 5500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.1228015124797821
#
# Current batch: 6000
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.12008913606405258
#
# Current batch: 6500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.12354286760091782
#
# Current batch: 7000
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.12368039041757584
#
# Current batch: 7500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.12605226039886475
#
# Total average train accuarcy: 0.010193162570853792
# Total average train loss: 0.127088371021502
#
# Time elapsed: 5648.284453392029
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.12127863615751266
#
# Current batch: 500
# Current batch average train accuracy: 0.0
# Current batch average train loss: 0.1244288757443428
#
# Current batch: 1000
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.11368642002344131
#
# Current batch: 1500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.11925247311592102
#
# Current batch: 2000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.11580554395914078
#
# Current batch: 2500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.11586813628673553
#
# Current batch: 3000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.11498319357633591
#
# Current batch: 3500
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.11706146597862244
#
# Current batch: 4000
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.11505352705717087
#
# Current batch: 4500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.1108175665140152
#
# Current batch: 5000
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.11346033215522766
#
# Current batch: 5500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.11190424114465714
#
# Current batch: 6000
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.11115346848964691
#
# Current batch: 6500
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.10491737723350525
#
# Current batch: 7000
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.11555664986371994
#
# Current batch: 7500
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.11412052065134048
#
# Total average train accuarcy: 0.029044704386056094
# Total average train loss: 0.11493132108350596
#
# Time elapsed: 7682.5299463272095
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.11002271622419357
#
# Current batch: 500
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.10152184218168259
#
# Current batch: 1000
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.10944276303052902
#
# Current batch: 1500
# Current batch average train accuracy: 0.109375
# Current batch average train loss: 0.10350997745990753
#
# Current batch: 2000
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.10666299611330032
#
# Current batch: 2500
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.10606563091278076
#
# Current batch: 3000
# Current batch average train accuracy: 0.03125
# Current batch average train loss: 0.10792417079210281
#
# Current batch: 3500
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.10158335417509079
#
# Current batch: 4000
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.10354524850845337
#
# Current batch: 4500
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.09572656452655792
#
# Current batch: 5000
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.10134071111679077
#
# Current batch: 5500
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.10241241753101349
#
# Current batch: 6000
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.09839195758104324
#
# Current batch: 6500
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.09984953701496124
#
# Current batch: 7000
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.10296094417572021
#
# Current batch: 7500
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.09265151619911194
#
# Total average train accuarcy: 0.06523542516351659
# Total average train loss: 0.1028053006357411
#
# Time elapsed: 9733.933731555939
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.046875
# Current batch average train loss: 0.09563469886779785
#
# Current batch: 500
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.08610117435455322
#
# Current batch: 1000
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.09417098760604858
#
# Current batch: 1500
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.09562364220619202
#
# Current batch: 2000
# Current batch average train accuracy: 0.109375
# Current batch average train loss: 0.09047582745552063
#
# Current batch: 2500
# Current batch average train accuracy: 0.140625
# Current batch average train loss: 0.08484137803316116
#
# Current batch: 3000
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.09157732129096985
#
# Current batch: 3500
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.09859123080968857
#
# Current batch: 4000
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.08975519239902496
#
# Current batch: 4500
# Current batch average train accuracy: 0.015625
# Current batch average train loss: 0.10593473166227341
#
# Current batch: 5000
# Current batch average train accuracy: 0.125
# Current batch average train loss: 0.09130292385816574
#
# Current batch: 5500
# Current batch average train accuracy: 0.140625
# Current batch average train loss: 0.09049016237258911
#
# Current batch: 6000
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.08620499819517136
#
# Current batch: 6500
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.08590877056121826
#
# Current batch: 7000
# Current batch average train accuracy: 0.0625
# Current batch average train loss: 0.08532580733299255
#
# Current batch: 7500
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.08101888000965118
#
# Total average train accuarcy: 0.11699410749190316
# Total average train loss: 0.09115944022637121
#
# Time elapsed: 11789.904147148132
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.09080820530653
#
# Current batch: 500
# Current batch average train accuracy: 0.140625
# Current batch average train loss: 0.07239985466003418
#
# Current batch: 1000
# Current batch average train accuracy: 0.140625
# Current batch average train loss: 0.08522391319274902
#
# Current batch: 1500
# Current batch average train accuracy: 0.109375
# Current batch average train loss: 0.08516067266464233
#
# Current batch: 2000
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07778289914131165
#
# Current batch: 2500
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07827751338481903
#
# Current batch: 3000
# Current batch average train accuracy: 0.125
# Current batch average train loss: 0.082755446434021
#
# Current batch: 3500
# Current batch average train accuracy: 0.109375
# Current batch average train loss: 0.09162630140781403
#
# Current batch: 4000
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07809766381978989
#
# Current batch: 4500
# Current batch average train accuracy: 0.15625
# Current batch average train loss: 0.08137595653533936
#
# Current batch: 5000
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07688136398792267
#
# Current batch: 5500
# Current batch average train accuracy: 0.21875
# Current batch average train loss: 0.08108706027269363
#
# Current batch: 6000
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.06369556486606598
#
# Current batch: 6500
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.08577179163694382
#
# Current batch: 7000
# Current batch average train accuracy: 0.09375
# Current batch average train loss: 0.0905093401670456
#
# Current batch: 7500
# Current batch average train accuracy: 0.265625
# Current batch average train loss: 0.06547775119543076
#
# Total average train accuarcy: 0.17541982336743284
# Total average train loss: 0.08070091778086498
#
# Time elapsed: 13848.405447006226
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.234375
# Current batch average train loss: 0.06802370399236679
#
# Current batch: 500
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07492072135210037
#
# Current batch: 1000
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.08345305919647217
#
# Current batch: 1500
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.08181214332580566
#
# Current batch: 2000
# Current batch average train accuracy: 0.21875
# Current batch average train loss: 0.07157356292009354
#
# Current batch: 2500
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.07399170845746994
#
# Current batch: 3000
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.07116883993148804
#
# Current batch: 3500
# Current batch average train accuracy: 0.125
# Current batch average train loss: 0.08293066918849945
#
# Current batch: 4000
# Current batch average train accuracy: 0.171875
# Current batch average train loss: 0.08324683457612991
#
# Current batch: 4500
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.07565295696258545
#
# Current batch: 5000
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.06581931561231613
#
# Current batch: 5500
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.07870151847600937
#
# Current batch: 6000
# Current batch average train accuracy: 0.203125
# Current batch average train loss: 0.07254628092050552
#
# Current batch: 6500
# Current batch average train accuracy: 0.28125
# Current batch average train loss: 0.06588578224182129
#
# Current batch: 7000
# Current batch average train accuracy: 0.328125
# Current batch average train loss: 0.0728817880153656
#
# Current batch: 7500
# Current batch average train accuracy: 0.234375
# Current batch average train loss: 0.08428223431110382
#
# Total average train accuarcy: 0.2345324210238819
# Total average train loss: 0.07203390000708992
#
# Time elapsed: 15906.112419605255
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.06291242688894272
#
# Current batch: 500
# Current batch average train accuracy: 0.28125
# Current batch average train loss: 0.062482062727212906
#
# Current batch: 1000
# Current batch average train accuracy: 0.265625
# Current batch average train loss: 0.06278528273105621
#
# Current batch: 1500
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.06158220022916794
#
# Current batch: 2000
# Current batch average train accuracy: 0.28125
# Current batch average train loss: 0.07038000971078873
#
# Current batch: 2500
# Current batch average train accuracy: 0.140625
# Current batch average train loss: 0.07534375786781311
#
# Current batch: 3000
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.059136297553777695
#
# Current batch: 3500
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.06945952028036118
#
# Current batch: 4000
# Current batch average train accuracy: 0.21875
# Current batch average train loss: 0.06970913708209991
#
# Current batch: 4500
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.06581887602806091
#
# Current batch: 5000
# Current batch average train accuracy: 0.265625
# Current batch average train loss: 0.06836579740047455
#
# Current batch: 5500
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.05661069601774216
#
# Current batch: 6000
# Current batch average train accuracy: 0.21875
# Current batch average train loss: 0.07023870944976807
#
# Current batch: 6500
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.06389491260051727
#
# Current batch: 7000
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.06220719963312149
#
# Current batch: 7500
# Current batch average train accuracy: 0.234375
# Current batch average train loss: 0.07097211480140686
#
# Total average train accuarcy: 0.28601798121979605
# Total average train loss: 0.06517812479917641
#
# Time elapsed: 17964.358783245087
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.06059979274868965
#
# Current batch: 500
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.0635179728269577
#
# Current batch: 1000
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.06260772794485092
#
# Current batch: 1500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.05072960630059242
#
# Current batch: 2000
# Current batch average train accuracy: 0.328125
# Current batch average train loss: 0.054483383893966675
#
# Current batch: 2500
# Current batch average train accuracy: 0.328125
# Current batch average train loss: 0.05957404524087906
#
# Current batch: 3000
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.04933787137269974
#
# Current batch: 3500
# Current batch average train accuracy: 0.296875
# Current batch average train loss: 0.05465558543801308
#
# Current batch: 4000
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.057309143245220184
#
# Current batch: 4500
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.05956108495593071
#
# Current batch: 5000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.048159413039684296
#
# Current batch: 5500
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.05363013222813606
#
# Current batch: 6000
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.04761355370283127
#
# Current batch: 6500
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.05538836866617203
#
# Current batch: 7000
# Current batch average train accuracy: 0.28125
# Current batch average train loss: 0.06048847734928131
#
# Current batch: 7500
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.046053268015384674
#
# Total average train accuarcy: 0.33221230965527504
# Total average train loss: 0.059654781157657336
#
# Time elapsed: 20022.26372718811
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.04941819980740547
#
# Current batch: 500
# Current batch average train accuracy: 0.265625
# Current batch average train loss: 0.06742216646671295
#
# Current batch: 1000
# Current batch average train accuracy: 0.3125
# Current batch average train loss: 0.056427549570798874
#
# Current batch: 1500
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.052058521658182144
#
# Current batch: 2000
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.05324753001332283
#
# Current batch: 2500
# Current batch average train accuracy: 0.265625
# Current batch average train loss: 0.055373623967170715
#
# Current batch: 3000
# Current batch average train accuracy: 0.25
# Current batch average train loss: 0.061430029571056366
#
# Current batch: 3500
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.047930631786584854
#
# Current batch: 4000
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.055814847350120544
#
# Current batch: 4500
# Current batch average train accuracy: 0.3125
# Current batch average train loss: 0.06028076633810997
#
# Current batch: 5000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.040793243795633316
#
# Current batch: 5500
# Current batch average train accuracy: 0.328125
# Current batch average train loss: 0.05474989861249924
#
# Current batch: 6000
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.05766930803656578
#
# Current batch: 6500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.05061079561710358
#
# Current batch: 7000
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.053969621658325195
#
# Current batch: 7500
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.0527062863111496
#
# Total average train accuarcy: 0.37350063083059704
# Total average train loss: 0.05512620386457249
#
# Time elapsed: 22080.03701400757
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.0501708984375
#
# Current batch: 500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04259922727942467
#
# Current batch: 1000
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.058854278177022934
#
# Current batch: 1500
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.059719767421483994
#
# Current batch: 2000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04845244064927101
#
# Current batch: 2500
# Current batch average train accuracy: 0.359375
# Current batch average train loss: 0.05707686394453049
#
# Current batch: 3000
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.05421602353453636
#
# Current batch: 3500
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.048818912357091904
#
# Current batch: 4000
# Current batch average train accuracy: 0.34375
# Current batch average train loss: 0.05820086598396301
#
# Current batch: 4500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.051022518426179886
#
# Current batch: 5000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.0499659962952137
#
# Current batch: 5500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.050566647201776505
#
# Current batch: 6000
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.05032666027545929
#
# Current batch: 6500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.04360422492027283
#
# Current batch: 7000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04990842193365097
#
# Current batch: 7500
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.053647179156541824
#
# Total average train accuarcy: 0.4112200202599552
# Total average train loss: 0.05130359591575434
#
# Time elapsed: 24138.61451482773
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04415259137749672
#
# Current batch: 500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.052618607878685
#
# Current batch: 1000
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.049919240176677704
#
# Current batch: 1500
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.050813477486371994
#
# Current batch: 2000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.05270891264081001
#
# Current batch: 2500
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.04528111219406128
#
# Current batch: 3000
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.041628945618867874
#
# Current batch: 3500
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.04175637662410736
#
# Current batch: 4000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.045830368995666504
#
# Current batch: 4500
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04245208576321602
#
# Current batch: 5000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04542892798781395
#
# Current batch: 5500
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.04884209856390953
#
# Current batch: 6000
# Current batch average train accuracy: 0.375
# Current batch average train loss: 0.05281565710902214
#
# Current batch: 6500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.04862501844763756
#
# Current batch: 7000
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.05032870173454285
#
# Current batch: 7500
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.04844310134649277
#
# Total average train accuarcy: 0.44301428999455794
# Total average train loss: 0.04803461936785087
#
# Time elapsed: 26194.91052007675
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.0469437912106514
#
# Current batch: 500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.04011198505759239
#
# Current batch: 1000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.04184002801775932
#
# Current batch: 1500
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04300487041473389
#
# Current batch: 2000
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.0494413897395134
#
# Current batch: 2500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.04101887345314026
#
# Current batch: 3000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04705227166414261
#
# Current batch: 3500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03854379057884216
#
# Current batch: 4000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.03918664902448654
#
# Current batch: 4500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04757489636540413
#
# Current batch: 5000
# Current batch average train accuracy: 0.390625
# Current batch average train loss: 0.05456434562802315
#
# Current batch: 5500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04452895000576973
#
# Current batch: 6000
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.04710642248392105
#
# Current batch: 6500
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.05505617335438728
#
# Current batch: 7000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.05408551171422005
#
# Current batch: 7500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.035568252205848694
#
# Total average train accuarcy: 0.47165338763164383
# Total average train loss: 0.045309343295647515
#
# Time elapsed: 28252.035737991333
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.03664139658212662
#
# Current batch: 500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.04171009361743927
#
# Current batch: 1000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03889309614896774
#
# Current batch: 1500
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.039937909692525864
#
# Current batch: 2000
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.04525071009993553
#
# Current batch: 2500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.04114637151360512
#
# Current batch: 3000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.050778478384017944
#
# Current batch: 3500
# Current batch average train accuracy: 0.40625
# Current batch average train loss: 0.047354556620121
#
# Current batch: 4000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03966784477233887
#
# Current batch: 4500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.042660608887672424
#
# Current batch: 5000
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.0386427566409111
#
# Current batch: 5500
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04072311520576477
#
# Current batch: 6000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.048830967396497726
#
# Current batch: 6500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04315377399325371
#
# Current batch: 7000
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.040869567543268204
#
# Current batch: 7500
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04687522351741791
#
# Total average train accuarcy: 0.49547412167794824
# Total average train loss: 0.04299883244501094
#
# Time elapsed: 30309.14162158966
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.04591339826583862
#
# Current batch: 500
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04090520367026329
#
# Current batch: 1000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.05040568858385086
#
# Current batch: 1500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04323475435376167
#
# Current batch: 2000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.041443124413490295
#
# Current batch: 2500
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.035309527069330215
#
# Current batch: 3000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.04190472885966301
#
# Current batch: 3500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.039286330342292786
#
# Current batch: 4000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.046866074204444885
#
# Current batch: 4500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.0331195630133152
#
# Current batch: 5000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.043276455253362656
#
# Current batch: 5500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.04237189143896103
#
# Current batch: 6000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03771141543984413
#
# Current batch: 6500
# Current batch average train accuracy: 0.4375
# Current batch average train loss: 0.05274266377091408
#
# Current batch: 7000
# Current batch average train accuracy: 0.5
# Current batch average train loss: 0.03944767266511917
#
# Current batch: 7500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.03893967345356941
#
# Total average train accuarcy: 0.5175664410351737
# Total average train loss: 0.040966228953385045
#
# Time elapsed: 32366.368932247162
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.028957471251487732
#
# Current batch: 500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03248102590441704
#
# Current batch: 1000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.05097825825214386
#
# Current batch: 1500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.043293703347444534
#
# Current batch: 2000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.043535929173231125
#
# Current batch: 2500
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.03176496550440788
#
# Current batch: 3000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03876497596502304
#
# Current batch: 3500
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.030548173934221268
#
# Current batch: 4000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03530951589345932
#
# Current batch: 4500
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.048393066972494125
#
# Current batch: 5000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.040946025401353836
#
# Current batch: 5500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.04548013210296631
#
# Current batch: 6000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03691001236438751
#
# Current batch: 6500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.045671891421079636
#
# Current batch: 7000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.04437241703271866
#
# Current batch: 7500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04647315666079521
#
# Total average train accuarcy: 0.5362426955116251
# Total average train loss: 0.039241465812378924
#
# Time elapsed: 34424.16482377052
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.03861046954989433
#
# Current batch: 500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.038397736847400665
#
# Current batch: 1000
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.03659213334321976
#
# Current batch: 1500
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.024700762704014778
#
# Current batch: 2000
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.0479104109108448
#
# Current batch: 2500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.0262815672904253
#
# Current batch: 3000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.0365331768989563
#
# Current batch: 3500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.033781468868255615
#
# Current batch: 4000
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.03185280039906502
#
# Current batch: 4500
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.043200865387916565
#
# Current batch: 5000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04544037580490112
#
# Current batch: 5500
# Current batch average train accuracy: 0.421875
# Current batch average train loss: 0.04785127192735672
#
# Current batch: 6000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.02834922820329666
#
# Current batch: 6500
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.03143690153956413
#
# Current batch: 7000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.032991066575050354
#
# Current batch: 7500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.04589713737368584
#
# Total average train accuarcy: 0.5525749913885
# Total average train loss: 0.037694050259492504
#
# Time elapsed: 36482.348865032196
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.026053473353385925
#
# Current batch: 500
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03741202875971794
#
# Current batch: 1000
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.03675348684191704
#
# Current batch: 1500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03734974190592766
#
# Current batch: 2000
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.04368971660733223
#
# Current batch: 2500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03695420175790787
#
# Current batch: 3000
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.030123136937618256
#
# Current batch: 3500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.04436750337481499
#
# Current batch: 4000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03155297785997391
#
# Current batch: 4500
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.05555657669901848
#
# Current batch: 5000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.0319676548242569
#
# Current batch: 5500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03761317953467369
#
# Current batch: 6000
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03360506892204285
#
# Current batch: 6500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.0329759456217289
#
# Current batch: 7000
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.0318225622177124
#
# Current batch: 7500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.04309699311852455
#
# Total average train accuarcy: 0.5672094459493338
# Total average train loss: 0.036400790767531006
#
# Time elapsed: 38540.667851924896
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.043637897819280624
#
# Current batch: 500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03503696620464325
#
# Current batch: 1000
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.03844667971134186
#
# Current batch: 1500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.03949454426765442
#
# Current batch: 2000
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.025880832225084305
#
# Current batch: 2500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.033996645361185074
#
# Current batch: 3000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.03788882493972778
#
# Current batch: 3500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.040004633367061615
#
# Current batch: 4000
# Current batch average train accuracy: 0.453125
# Current batch average train loss: 0.04180597513914108
#
# Current batch: 4500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03571746498346329
#
# Current batch: 5000
# Current batch average train accuracy: 0.484375
# Current batch average train loss: 0.046794649213552475
#
# Current batch: 5500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.032777126878499985
#
# Current batch: 6000
# Current batch average train accuracy: 0.46875
# Current batch average train loss: 0.045295245945453644
#
# Current batch: 6500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.042696960270404816
#
# Current batch: 7000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03567361831665039
#
# Current batch: 7500
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.03028710000216961
#
# Total average train accuarcy: 0.579911663334169
# Total average train loss: 0.035213715081452795
#
# Time elapsed: 40599.048649311066
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.03403541073203087
#
# Current batch: 500
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.0328347384929657
#
# Current batch: 1000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.030379116535186768
#
# Current batch: 1500
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.027810372412204742
#
# Current batch: 2000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.029104819521307945
#
# Current batch: 2500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03063267469406128
#
# Current batch: 3000
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.0368705615401268
#
# Current batch: 3500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.034442365169525146
#
# Current batch: 4000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.027730967849493027
#
# Current batch: 4500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03169844299554825
#
# Current batch: 5000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.0313456691801548
#
# Current batch: 5500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.02900593727827072
#
# Current batch: 6000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.028358494862914085
#
# Current batch: 6500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.03588341176509857
#
# Current batch: 7000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03519870340824127
#
# Current batch: 7500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03250061348080635
#
# Total average train accuarcy: 0.5929542642721601
# Total average train loss: 0.03407453131311792
#
# Time elapsed: 42656.0222799778
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.03653618320822716
#
# Current batch: 500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.02480217069387436
#
# Current batch: 1000
# Current batch average train accuracy: 0.71875
# Current batch average train loss: 0.026086952537298203
#
# Current batch: 1500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.039188507944345474
#
# Current batch: 2000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03129953891038895
#
# Current batch: 2500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03534478694200516
#
# Current batch: 3000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03260199353098869
#
# Current batch: 3500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03970292583107948
#
# Current batch: 4000
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.03429347276687622
#
# Current batch: 4500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.028617335483431816
#
# Current batch: 5000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03659890592098236
#
# Current batch: 5500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.030845260247588158
#
# Current batch: 6000
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.02609802410006523
#
# Current batch: 6500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03112267702817917
#
# Current batch: 7000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03976602107286453
#
# Current batch: 7500
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03419379144906998
#
# Total average train accuarcy: 0.6034531605733934
# Total average train loss: 0.033071072254429366
#
# Time elapsed: 44713.1823720932
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.028522484004497528
#
# Current batch: 500
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.035598497837781906
#
# Current batch: 1000
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.023811930790543556
#
# Current batch: 1500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.03603814169764519
#
# Current batch: 2000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.029795335605740547
#
# Current batch: 2500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.039289407432079315
#
# Current batch: 3000
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03468857705593109
#
# Current batch: 3500
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.046022798866033554
#
# Current batch: 4000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.035965897142887115
#
# Current batch: 4500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.025957241654396057
#
# Current batch: 5000
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.026744510978460312
#
# Current batch: 5500
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.04780334606766701
#
# Current batch: 6000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.03334544599056244
#
# Current batch: 6500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03979969397187233
#
# Current batch: 7000
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.02457498572766781
#
# Current batch: 7500
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.026029126718640327
#
# Total average train accuarcy: 0.613271289768315
# Total average train loss: 0.03218700299118469
#
# Time elapsed: 46771.35042977333
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.042426854372024536
#
# Current batch: 500
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.027658266946673393
#
# Current batch: 1000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.031533677130937576
#
# Current batch: 1500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.037502896040678024
#
# Current batch: 2000
# Current batch average train accuracy: 0.625
# Current batch average train loss: 0.027659770101308823
#
# Current batch: 2500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.029606832191348076
#
# Current batch: 3000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.0280753243714571
#
# Current batch: 3500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.03755859285593033
#
# Current batch: 4000
# Current batch average train accuracy: 0.5625
# Current batch average train loss: 0.03542160242795944
#
# Current batch: 4500
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03854610398411751
#
# Current batch: 5000
# Current batch average train accuracy: 0.515625
# Current batch average train loss: 0.03469601646065712
#
# Current batch: 5500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.037094596773386
#
# Current batch: 6000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.03379610553383827
#
# Current batch: 6500
# Current batch average train accuracy: 0.578125
# Current batch average train loss: 0.03404201939702034
#
# Current batch: 7000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.033394329249858856
#
# Current batch: 7500
# Current batch average train accuracy: 0.65625
# Current batch average train loss: 0.03419113904237747
#
# Total average train accuarcy: 0.6220927270021992
# Total average train loss: 0.031355054135539046
#
# Time elapsed: 48829.83195590973
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.02640177682042122
#
# Current batch: 500
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.023477530106902122
#
# Current batch: 1000
# Current batch average train accuracy: 0.546875
# Current batch average train loss: 0.030720748007297516
#
# Current batch: 1500
# Current batch average train accuracy: 0.53125
# Current batch average train loss: 0.039814360439777374
#
# Current batch: 2000
# Current batch average train accuracy: 0.6875
# Current batch average train loss: 0.023270133882761
#
# Current batch: 2500
# Current batch average train accuracy: 0.609375
# Current batch average train loss: 0.03515582159161568
#
# Current batch: 3000
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.028944864869117737
#
# Current batch: 3500
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.028957294300198555
#
# Current batch: 4000
# Current batch average train accuracy: 0.671875
# Current batch average train loss: 0.023963777348399162
#
# Current batch: 4500
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.025005478411912918
#
# Current batch: 5000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.03709830343723297
#
# Current batch: 5500
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.02725744992494583
#
# Current batch: 6000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.03281853720545769
#
# Current batch: 6500
# Current batch average train accuracy: 0.703125
# Current batch average train loss: 0.027167197316884995
#
# Current batch: 7000
# Current batch average train accuracy: 0.640625
# Current batch average train loss: 0.02736637555062771
#
# Current batch: 7500
# Current batch average train accuracy: 0.59375
# Current batch average train loss: 0.03210340440273285
#
# Total average train accuarcy: 0.6306614243523031
# Total average train loss: 0.03053212074850404
#
# Time elapsed: 50886.86534523964
# ...
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.011177582666277885
#
# Current batch: 2500
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.008694679476320744
#
# Current batch: 3000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009207089431583881
#
# Current batch: 3500
# Current batch average train accuracy: 0.796875
# Current batch average train loss: 0.0116230808198452
#
# Current batch: 4000
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.008987287990748882
#
# Current batch: 4500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008905996568500996
#
# Current batch: 5000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008617815561592579
#
# Current batch: 5500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.005196777172386646
#
# Current batch: 6000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.015193239785730839
#
# Current batch: 6500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.009423579089343548
#
# Current batch: 7000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01045569684356451
#
# Current batch: 7500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.004979967605322599
#
# Total average train accuarcy: 0.8686262160559126
# Total average train loss: 0.009084217417058591
#
# Time elapsed: 233998.21756768227
#
# [ Train epoch: 112 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.00991840474307537
#
# Current batch: 500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0058191679418087006
#
# Current batch: 1000
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0069787222892045975
#
# Current batch: 1500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.00658536097034812
#
# Current batch: 2000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.010360836051404476
#
# Current batch: 2500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008999571204185486
#
# Current batch: 3000
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.008287278935313225
#
# Current batch: 3500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.005880238953977823
#
# Current batch: 4000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01277245208621025
#
# Current batch: 4500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.008476676419377327
#
# Current batch: 5000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.010017374530434608
#
# Current batch: 5500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.012047712691128254
#
# Current batch: 6000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009423600509762764
#
# Current batch: 6500
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.011058756150305271
#
# Current batch: 7000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.007341115269809961
#
# Current batch: 7500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00903606228530407
#
# Total average train accuarcy: 0.8690195934556676
# Total average train loss: 0.00905165324585706
#
# Time elapsed: 236054.37370967865
#
# [ Train epoch: 113 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.01170902606099844
#
# Current batch: 500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.012064343318343163
#
# Current batch: 1000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.014653759077191353
#
# Current batch: 1500
# Current batch average train accuracy: 0.796875
# Current batch average train loss: 0.014015492051839828
#
# Current batch: 2000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.005101883318275213
#
# Current batch: 2500
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.014800025150179863
#
# Current batch: 3000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.012177573516964912
#
# Current batch: 3500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.0061416951939463615
#
# Current batch: 4000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01074044220149517
#
# Current batch: 4500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.012279817834496498
#
# Current batch: 5000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.014301049523055553
#
# Current batch: 5500
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.007082602009177208
#
# Current batch: 6000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.007948321290314198
#
# Current batch: 6500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011357860639691353
#
# Current batch: 7000
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.008024758659303188
#
# Current batch: 7500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00454911682754755
#
# Total average train accuarcy: 0.8690827784266127
# Total average train loss: 0.00904450269515659
#
# Time elapsed: 238110.42093110085
#
# [ Train epoch: 114 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.010039536282420158
#
# Current batch: 500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.005146755836904049
#
# Current batch: 1000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.009956150315701962
#
# Current batch: 1500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.011443881317973137
#
# Current batch: 2000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008580189198255539
#
# Current batch: 2500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008736657910048962
#
# Current batch: 3000
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.007430661469697952
#
# Current batch: 3500
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.010697076097130775
#
# Current batch: 4000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.010343631729483604
#
# Current batch: 4500
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.008746416307985783
#
# Current batch: 5000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.00972084328532219
#
# Current batch: 5500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.0072815632447600365
#
# Current batch: 6000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.012853380292654037
#
# Current batch: 6500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.006811177358031273
#
# Current batch: 7000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.011574761010706425
#
# Current batch: 7500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.01398815494030714
#
# Total average train accuarcy: 0.8694863469507137
# Total average train loss: 0.009004706456926734
#
# Time elapsed: 240166.26526379585
#
# [ Train epoch: 115 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.012775646522641182
#
# Current batch: 500
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.011166343465447426
#
# Current batch: 1000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.012609587050974369
#
# Current batch: 1500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008728434331715107
#
# Current batch: 2000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01529416162520647
#
# Current batch: 2500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0061002993024885654
#
# Current batch: 3000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.00974054541438818
#
# Current batch: 3500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.008364270441234112
#
# Current batch: 4000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.014926808886229992
#
# Current batch: 4500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.008814828470349312
#
# Current batch: 5000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.011571469716727734
#
# Current batch: 5500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.005582930985838175
#
# Current batch: 6000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.012689981609582901
#
# Current batch: 6500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.006490861531347036
#
# Current batch: 7000
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.005281181074678898
#
# Current batch: 7500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.008544625714421272
#
# Total average train accuarcy: 0.8689910583074988
# Total average train loss: 0.009038213668310072
#
# Time elapsed: 242218.95087766647
#
# [ Train epoch: 116 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.009980974718928337
#
# Current batch: 500
# Current batch average train accuracy: 0.890625
# Current batch average train loss: 0.00876128301024437
#
# Current batch: 1000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.009262091480195522
#
# Current batch: 1500
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.011299921199679375
#
# Current batch: 2000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.00679231621325016
#
# Current batch: 2500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.009362892247736454
#
# Current batch: 3000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.006374678108841181
#
# Current batch: 3500
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.013813451863825321
#
# Current batch: 4000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.012676496990025043
#
# Current batch: 4500
# Current batch average train accuracy: 0.859375
# Current batch average train loss: 0.008480511605739594
#
# Current batch: 5000
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.009997430257499218
#
# Current batch: 5500
# Current batch average train accuracy: 0.84375
# Current batch average train loss: 0.007539340294897556
#
# Current batch: 6000
# Current batch average train accuracy: 0.828125
# Current batch average train loss: 0.010798271745443344
#
# Current batch: 6500
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006091761402785778
#
# Current batch: 7000
# Current batch average train accuracy: 0.8125
# Current batch average train loss: 0.01232307218015194
#
# Current batch: 7500
# Current batch average train accuracy: 0.953125
# Current batch average train loss: 0.006510251667350531
#
# Total average train accuarcy: 0.8698083864800468
# Total average train loss: 0.00899272158026419
#
# Time elapsed: 244271.72563552856
#
# [ Train epoch: 117 ]
#
# Current batch: 0
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.009849296882748604
#
# Current batch: 500
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.0074835545383393764
#
# Current batch: 1000
# Current batch average train accuracy: 0.875
# Current batch average train loss: 0.014681474305689335
#
# Current batch: 1500
# Current batch average train accuracy: 0.921875
# Current batch average train loss: 0.0066185882315039635
#
# Current batch: 2000
# Current batch average train accuracy: 0.78125
# Current batch average train loss: 0.013343758881092072
#
# Current batch: 2500
# Current batch average train accuracy: 0.765625
# Current batch average train loss: 0.013416072353720665
#
# Current batch: 3000
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.006646039430052042
#
# Current batch: 3500
# Current batch average train accuracy: 0.90625
# Current batch average train loss: 0.008190905675292015
#
# Current batch: 4000
# Current batch average train accuracy: 0.9375
# Current batch average train loss: 0.006850991398096085
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-58a8d4b67ffe> in <module>
#       1 for epoch in range(0, 120):
#       2     adjust_learning_rate(optimizer, epoch)
# ----> 3     train(epoch)
#       4     #test(epoch)
#       5     print('\nTime elapsed:', time.time() - start_time)
#
# <ipython-input-7-59ce27245180> in train(epoch)
#      21     total = 0
#      22
# ---> 23     for batch_idx, (inputs, targets) in enumerate(train_loader):
#      24         inputs, targets = inputs.to(device), targets.to(device)
#      25         #optimizer.zero_grad()
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     436         if self._sampler_iter is None:
#     437             self._reset()
# --> 438         data = self._next_data()
#     439         self._num_yielded += 1
#     440         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1086             else:
#    1087                 del self._task_info[idx]
# -> 1088                 return self._process_data(data)
#    1089
#    1090     def _try_put_index(self):
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1112         self._try_put_index()
#    1113         if isinstance(data, ExceptionWrapper):
# -> 1114             data.reraise()
#    1115         return data
#    1116
#
# /opt/conda/lib/python3.6/site-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/worker.py", line 202, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py", line 47, in fetch
#     return self.collate_fn(data)
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py", line 83, in default_collate
#     return [default_collate(samples) for samples in transposed]
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py", line 83, in <listcomp>
#     return [default_collate(samples) for samples in transposed]
#   File "/opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py", line 53, in default_collate
#     storage = elem.storage()._new_shared(numel)
#   File "/opt/conda/lib/python3.6/site-packages/torch/storage.py", line 137, in _new_shared
#     return cls._new_using_fd(size)
# RuntimeError: unable to write to file </torch_2170_2038028996>

# %%
# count_parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
    state = {
        'net': net.state_dict()
    }

    file_name = 'CNN.pt'
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved')
