# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib.image import imread
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import time

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    print("error")

# %%
#dataset
transformer = transforms.Compose([transforms.Resize((32, 32)),
                                  transforms.ToTensor(),
                                  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                 ])
train_dataset = torchvision.datasets.CIFAR10(root='./data',
                                        train=True,
                                        download=True,
                                        transform=transformer
)
test_dataset = torchvision.datasets.CIFAR10(root='./data',
                                       train=False,
                                       download=True,
                                       transform=transformer

)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                          batch_size=32,
                                          shuffle=True,
                                          num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset,
                                         batch_size=32,
                                         shuffle=False,
                                         num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class CNN_depthwise(nn.Module):
 
    def __init__(self):
      
        super(CNN_depthwise, self).__init__()

        def conv_dw(inp, oup):
              return nn.Sequential(
                  # dw
                  nn.Conv2d(inp, inp, 3, 1, 1, groups=inp, bias=False),
                  nn.BatchNorm2d(inp),
                  nn.ReLU(inplace=True),

                  # pw
                  nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
                  nn.BatchNorm2d(oup),
                  nn.ReLU(inplace=True),
                  )
              
        self.conv_layer = nn.Sequential(

            conv_dw(3,32),
            conv_dw(32,64),
            conv_dw(64,128),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.05),
            conv_dw(128,256),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )


        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),
            nn.Linear(16384, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(512, 10)
        )


    def forward(self, x):

        x = self.conv_layer(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layer(x)

        return x

# %%
train_losses = []
train_accuracy = [] 
test_losses = []
test_accuracy = []

def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()

        outputs = net(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, prediction = outputs.max(1)

        total += labels.size(0)
        correct += prediction.eq(labels).sum().item()

        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current train accuracy:', str(prediction.eq(labels).sum().item() / labels.size(0)))
            print('Current train average loss:', loss.item() / labels.size(0))

            train_losses.append(loss.item() / labels.size(0))
            train_accuracy.append(prediction.eq(labels).sum().item() / labels.size(0))
            
    print('\nTrain accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)

# %%
def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (images, labels) in enumerate(test_loader):
        images = images.to(device)
        labels = labels.to(device)
        total += labels.size(0)

        outputs = net(images)
        loss += criterion(outputs, labels).item()

        _, prediction = outputs.max(1)
        correct += prediction.eq(labels).sum().item()

    print('\nTest accuarcy:', correct / total)
    print('Test average loss:', loss / total)
    test_losses.append(loss / total)
    test_accuracy.append(correct / total)

    state = {
        'net': net.state_dict()
    }

    file_name = 'CNN_depthwise.pt'
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved')

# %%
# count_parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(count_parameters(net)/1000000,str('M'))
# Out:
# 18.092395 M

# %%
net = CNN_depthwise()
net = net.to(device)

learning_rate = 0.1
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0001)

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    #if epoch >= 50:
    if epoch >= 50:
        lr /= 10
    #if epoch >= 100:
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
start_time = time.time()

for epoch in range(0, 60):
    #adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
    print('\nTime elapsed:', time.time() - start_time)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current train accuracy: 0.46875
# Current train average loss: 0.04435192421078682
#
# Current batch: 100
# Current train accuracy: 0.3125
# Current train average loss: 0.06156992167234421
#
# Current batch: 200
# Current train accuracy: 0.53125
# Current train average loss: 0.04536440223455429
#
# Current batch: 300
# Current train accuracy: 0.5625
# Current train average loss: 0.04251411184668541
#
# Current batch: 400
# Current train accuracy: 0.46875
# Current train average loss: 0.040414806455373764
#
# Current batch: 500
# Current train accuracy: 0.4375
# Current train average loss: 0.04394867271184921
#
# Current batch: 600
# Current train accuracy: 0.375
# Current train average loss: 0.0555223748087883
#
# Current batch: 700
# Current train accuracy: 0.53125
# Current train average loss: 0.035321880131959915
#
# Current batch: 800
# Current train accuracy: 0.3125
# Current train average loss: 0.04969673976302147
#
# Current batch: 900
# Current train accuracy: 0.40625
# Current train average loss: 0.05638803914189339
#
# Current batch: 1000
# Current train accuracy: 0.46875
# Current train average loss: 0.050821367651224136
#
# Current batch: 1100
# Current train accuracy: 0.40625
# Current train average loss: 0.04816865175962448
#
# Current batch: 1200
# Current train accuracy: 0.4375
# Current train average loss: 0.05118211358785629
#
# Current batch: 1300
# Current train accuracy: 0.5
# Current train average loss: 0.05316079035401344
#
# Current batch: 1400
# Current train accuracy: 0.40625
# Current train average loss: 0.050448935478925705
#
# Current batch: 1500
# Current train accuracy: 0.1875
# Current train average loss: 0.05721380561590195
#
# Train accuarcy: 40.458
# Train average loss: 0.051733587075471876
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 37.71
# Test average loss: 0.052341425824165344
# Model Saved
#
# Time elapsed: 180.55295252799988
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current train accuracy: 0.28125
# Current train average loss: 0.05264749005436897
#
# Current batch: 100
# Current train accuracy: 0.34375
# Current train average loss: 0.05270114541053772
#
# Current batch: 200
# Current train accuracy: 0.65625
# Current train average loss: 0.03544769436120987
#
# Current batch: 300
# Current train accuracy: 0.34375
# Current train average loss: 0.047069065272808075
#
# Current batch: 400
# Current train accuracy: 0.53125
# Current train average loss: 0.04551216959953308
#
# Current batch: 500
# Current train accuracy: 0.53125
# Current train average loss: 0.0411042794585228
#
# Current batch: 600
# Current train accuracy: 0.4375
# Current train average loss: 0.04642845317721367
#
# Current batch: 700
# Current train accuracy: 0.4375
# Current train average loss: 0.05717812478542328
#
# Current batch: 800
# Current train accuracy: 0.46875
# Current train average loss: 0.045760661363601685
#
# Current batch: 900
# Current train accuracy: 0.46875
# Current train average loss: 0.0501527339220047
#
# Current batch: 1000
# Current train accuracy: 0.46875
# Current train average loss: 0.05203961953520775
#
# Current batch: 1100
# Current train accuracy: 0.375
# Current train average loss: 0.0635816901922226
#
# Current batch: 1200
# Current train accuracy: 0.34375
# Current train average loss: 0.05650508776307106
#
# Current batch: 1300
# Current train accuracy: 0.4375
# Current train average loss: 0.048495713621377945
#
# Current batch: 1400
# Current train accuracy: 0.375
# Current train average loss: 0.048451825976371765
#
# Current batch: 1500
# Current train accuracy: 0.25
# Current train average loss: 0.05243506655097008
#
# Train accuarcy: 41.612
# Train average loss: 0.05094784133434296
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 40.55
# Test average loss: 0.050677339267730714
# Model Saved
#
# Time elapsed: 365.96924901008606
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current train accuracy: 0.25
# Current train average loss: 0.05690048635005951
#
# Current batch: 100
# Current train accuracy: 0.40625
# Current train average loss: 0.0535646453499794
#
# Current batch: 200
# Current train accuracy: 0.4375
# Current train average loss: 0.04533129930496216
#
# Current batch: 300
# Current train accuracy: 0.53125
# Current train average loss: 0.04405107721686363
#
# Current batch: 400
# Current train accuracy: 0.25
# Current train average loss: 0.055907003581523895
#
# Current batch: 500
# Current train accuracy: 0.4375
# Current train average loss: 0.0481751412153244
#
# Current batch: 600
# Current train accuracy: 0.375
# Current train average loss: 0.04274403303861618
#
# Current batch: 700
# Current train accuracy: 0.375
# Current train average loss: 0.05601062253117561
#
# Current batch: 800
# Current train accuracy: 0.5
# Current train average loss: 0.050797682255506516
#
# Current batch: 900
# Current train accuracy: 0.40625
# Current train average loss: 0.047895416617393494
#
# Current batch: 1000
# Current train accuracy: 0.375
# Current train average loss: 0.04865633696317673
#
# Current batch: 1100
# Current train accuracy: 0.53125
# Current train average loss: 0.04967401176691055
#
# Current batch: 1200
# Current train accuracy: 0.375
# Current train average loss: 0.0588691383600235
#
# Current batch: 1300
# Current train accuracy: 0.46875
# Current train average loss: 0.05029910057783127
#
# Current batch: 1400
# Current train accuracy: 0.375
# Current train average loss: 0.05361829325556755
#
# Current batch: 1500
# Current train accuracy: 0.375
# Current train average loss: 0.04967910051345825
#
# Train accuarcy: 41.534
# Train average loss: 0.05098180014371872
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 44.16
# Test average loss: 0.04809394035339355
# Model Saved
#
# Time elapsed: 555.064893245697
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current train accuracy: 0.59375
# Current train average loss: 0.03693345561623573
#
# Current batch: 100
# Current train accuracy: 0.4375
# Current train average loss: 0.046990349888801575
#
# Current batch: 200
# Current train accuracy: 0.46875
# Current train average loss: 0.043205320835113525
#
# Current batch: 300
# Current train accuracy: 0.375
# Current train average loss: 0.05154886469244957
#
# Current batch: 400
# Current train accuracy: 0.5
# Current train average loss: 0.04846611246466637
#
# Current batch: 500
# Current train accuracy: 0.5
# Current train average loss: 0.04514612257480621
#
# Current batch: 600
# Current train accuracy: 0.59375
# Current train average loss: 0.04098204895853996
#
# Current batch: 700
# Current train accuracy: 0.625
# Current train average loss: 0.04241302236914635
#
# Current batch: 800
# Current train accuracy: 0.46875
# Current train average loss: 0.05087221786379814
#
# Current batch: 900
# Current train accuracy: 0.34375
# Current train average loss: 0.0660848543047905
#
# Current batch: 1000
# Current train accuracy: 0.5
# Current train average loss: 0.04962019622325897
#
# Current batch: 1100
# Current train accuracy: 0.65625
# Current train average loss: 0.03590337187051773
#
# Current batch: 1200
# Current train accuracy: 0.375
# Current train average loss: 0.058562640100717545
#
# Current batch: 1300
# Current train accuracy: 0.375
# Current train average loss: 0.04789411276578903
#
# Current batch: 1400
# Current train accuracy: 0.40625
# Current train average loss: 0.05284532159566879
#
# Current batch: 1500
# Current train accuracy: 0.40625
# Current train average loss: 0.049145523458719254
#
# Train accuarcy: 42.256
# Train average loss: 0.050571983479261395
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 33.05
# Test average loss: 0.061274396884441376
# Model Saved
#
# Time elapsed: 746.1449737548828
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current train accuracy: 0.25
# Current train average loss: 0.06713079661130905
#
# Current batch: 100
# Current train accuracy: 0.3125
# Current train average loss: 0.06677351146936417
#
# Current batch: 200
# Current train accuracy: 0.25
# Current train average loss: 0.06834454089403152
#
# Current batch: 300
# Current train accuracy: 0.375
# Current train average loss: 0.04880639165639877
#
# Current batch: 400
# Current train accuracy: 0.4375
# Current train average loss: 0.03990375995635986
#
# Current batch: 500
# Current train accuracy: 0.5
# Current train average loss: 0.04593243449926376
#
# Current batch: 600
# Current train accuracy: 0.34375
# Current train average loss: 0.055360130965709686
#
# Current batch: 700
# Current train accuracy: 0.375
# Current train average loss: 0.04754813760519028
#
# Current batch: 800
# Current train accuracy: 0.40625
# Current train average loss: 0.044197458773851395
#
# Current batch: 900
# Current train accuracy: 0.40625
# Current train average loss: 0.04893428087234497
# Current batch: 1000
# Current train accuracy: 0.375
# Current train average loss: 0.0637686476111412
#
# Current batch: 1100
# Current train accuracy: 0.53125
# Current train average loss: 0.043344367295503616
#
# Current batch: 1200
# Current train accuracy: 0.375
# Current train average loss: 0.0474226176738739
#
# Current batch: 1300
# Current train accuracy: 0.25
# Current train average loss: 0.06489095836877823
#
# Current batch: 1400
# Current train accuracy: 0.3125
# Current train average loss: 0.053213443607091904
#
# Current batch: 1500
# Current train accuracy: 0.5
# Current train average loss: 0.05090290680527687
#
# Train accuarcy: 39.478
# Train average loss: 0.052255205426216124
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 39.97
# Test average loss: 0.05186819677352905
# Model Saved
#
# Time elapsed: 938.1019401550293
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current train accuracy: 0.3125
# Current train average loss: 0.05810079351067543
#
# Current batch: 100
# Current train accuracy: 0.375
# Current train average loss: 0.04289470613002777
#
# Current batch: 200
# Current train accuracy: 0.5
# Current train average loss: 0.043908748775720596
#
# Current batch: 300
# Current train accuracy: 0.40625
# Current train average loss: 0.057014837861061096
#
# Current batch: 400
# Current train accuracy: 0.34375
# Current train average loss: 0.0590059831738472
#
# Current batch: 500
# Current train accuracy: 0.25
# Current train average loss: 0.06150861456990242
#
# Current batch: 600
# Current train accuracy: 0.3125
# Current train average loss: 0.056061699986457825
#
# Current batch: 700
# Current train accuracy: 0.375
# Current train average loss: 0.05192594602704048
#
# Current batch: 800
# Current train accuracy: 0.375
# Current train average loss: 0.05191910266876221
#
# Current batch: 900
# Current train accuracy: 0.3125
# Current train average loss: 0.06180409714579582
#
# Current batch: 1000
# Current train accuracy: 0.28125
# Current train average loss: 0.05931490287184715
#
# Current batch: 1100
# Current train accuracy: 0.53125
# Current train average loss: 0.048691075295209885
#
# Current batch: 1200
# Current train accuracy: 0.5
# Current train average loss: 0.04651004821062088
#
# Current batch: 1300
# Current train accuracy: 0.375
# Current train average loss: 0.057775720953941345
#
# Current batch: 1400
# Current train accuracy: 0.34375
# Current train average loss: 0.054793983697891235
#
# Current batch: 1500
# Current train accuracy: 0.21875
# Current train average loss: 0.06481462717056274
#
# Train accuarcy: 38.486
# Train average loss: 0.053220603325366975
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 37.82
# Test average loss: 0.0533501433134079
# Model Saved
#
# Time elapsed: 1131.9851639270782
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current train accuracy: 0.3125
# Current train average loss: 0.055739495903253555
#
# Current batch: 100
# Current train accuracy: 0.3125
# Current train average loss: 0.056955642998218536
#
# Current batch: 200
# Current train accuracy: 0.46875
# Current train average loss: 0.05289776623249054
#
# Current batch: 300
# Current train accuracy: 0.34375
# Current train average loss: 0.05948830023407936
#
# Current batch: 400
# Current train accuracy: 0.40625
# Current train average loss: 0.048302117735147476
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.05213684216141701
#
# Current batch: 600
# Current train accuracy: 0.34375
# Current train average loss: 0.061965055763721466
#
# Current batch: 700
# Current train accuracy: 0.25
# Current train average loss: 0.0821007788181305
#
# Current batch: 800
# Current train accuracy: 0.46875
# Current train average loss: 0.04825149476528168
#
# Current batch: 900
# Current train accuracy: 0.46875
# Current train average loss: 0.05180218815803528
#
# Current batch: 1000
# Current train accuracy: 0.53125
# Current train average loss: 0.04018962383270264
#
# Current batch: 1100
# Current train accuracy: 0.5
# Current train average loss: 0.04295917600393295
#
# Current batch: 1200
# Current train accuracy: 0.46875
# Current train average loss: 0.04319338873028755
#
# Current batch: 1300
# Current train accuracy: 0.3125
# Current train average loss: 0.06246931105852127
#
# Current batch: 1400
# Current train accuracy: 0.4375
# Current train average loss: 0.059002835303545
#
# Current batch: 1500
# Current train accuracy: 0.375
# Current train average loss: 0.06394120305776596
#
# Train accuarcy: 40.142
# Train average loss: 0.05199040343761444
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 40.34
# Test average loss: 0.056174330794811246
# Model Saved
#
# Time elapsed: 1326.2212824821472
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current train accuracy: 0.5
# Current train average loss: 0.04693937301635742
#
# Current batch: 100
# Current train accuracy: 0.40625
# Current train average loss: 0.047164689749479294
#
# Current batch: 200
# Current train accuracy: 0.40625
# Current train average loss: 0.05544514209032059
#
# Current batch: 300
# Current train accuracy: 0.46875
# Current train average loss: 0.05009491369128227
#
# Current batch: 400
# Current train accuracy: 0.25
# Current train average loss: 0.05742277577519417
#
# Current batch: 500
# Current train accuracy: 0.53125
# Current train average loss: 0.04921283200383186
#
# Current batch: 600
# Current train accuracy: 0.25
# Current train average loss: 0.057989701628685
#
# Current batch: 700
# Current train accuracy: 0.4375
# Current train average loss: 0.049658067524433136
#
# Current batch: 800
# Current train accuracy: 0.34375
# Current train average loss: 0.051513221114873886
#
# Current batch: 900
# Current train accuracy: 0.4375
# Current train average loss: 0.047276727855205536
#
# Current batch: 1000
# Current train accuracy: 0.375
# Current train average loss: 0.04863596707582474
#
# Current batch: 1100
# Current train accuracy: 0.34375
# Current train average loss: 0.05277184769511223
#
# Current batch: 1200
# Current train accuracy: 0.375
# Current train average loss: 0.05109329894185066
#
# Current batch: 1300
# Current train accuracy: 0.375
# Current train average loss: 0.04614092409610748
#
# Current batch: 1400
# Current train accuracy: 0.625
# Current train average loss: 0.039690952748060226
#
# Current batch: 1500
# Current train accuracy: 0.34375
# Current train average loss: 0.05397859960794449
#
# Train accuarcy: 40.624
# Train average loss: 0.051555744676589965
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 40.78
# Test average loss: 0.05037741339206696
# Model Saved
#
# Time elapsed: 1522.1244502067566
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current train accuracy: 0.34375
# Current train average loss: 0.05837251618504524
#
# Current batch: 100
# Current train accuracy: 0.5
# Current train average loss: 0.04277900606393814
#
# Current batch: 200
# Current train accuracy: 0.59375
# Current train average loss: 0.04287845268845558
#
# Current batch: 300
# Current train accuracy: 0.28125
# Current train average loss: 0.05537933483719826
#
# Current batch: 400
# Current train accuracy: 0.4375
# Current train average loss: 0.05415881797671318
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.061256539076566696
#
# Current batch: 600
# Current train accuracy: 0.3125
# Current train average loss: 0.05455075204372406
#
# Current batch: 700
# Current train accuracy: 0.46875
# Current train average loss: 0.05844157934188843
#
# Current batch: 800
# Current train accuracy: 0.40625
# Current train average loss: 0.05050153657793999
#
# Current batch: 900
# Current train accuracy: 0.46875
# Current train average loss: 0.055020518600940704
#
# Current batch: 1000
# Current train accuracy: 0.34375
# Current train average loss: 0.04694084823131561
#
# Current batch: 1100
# Current train accuracy: 0.3125
# Current train average loss: 0.056940726935863495
#
# Current batch: 1200
# Current train accuracy: 0.4375
# Current train average loss: 0.050544362515211105
#
# Current batch: 1300
# Current train accuracy: 0.28125
# Current train average loss: 0.055249083787202835
#
# Current batch: 1400
# Current train accuracy: 0.34375
# Current train average loss: 0.05623431131243706
#
# Current batch: 1500
# Current train accuracy: 0.59375
# Current train average loss: 0.04016825556755066
#
# Train accuarcy: 40.91
# Train average loss: 0.051434211933612826
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 38.14
# Test average loss: 0.05320435851812363
# Model Saved
#
# Time elapsed: 1717.769657611847
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current train accuracy: 0.625
# Current train average loss: 0.04110521823167801
#
# Current batch: 100
# Current train accuracy: 0.46875
# Current train average loss: 0.04836766794323921
# Current batch: 200
# Current train accuracy: 0.25
# Current train average loss: 0.06334473937749863
#
# Current batch: 300
# Current train accuracy: 0.53125
# Current train average loss: 0.04228299856185913
#
# Current batch: 400
# Current train accuracy: 0.375
# Current train average loss: 0.051927853375673294
#
# Current batch: 500
# Current train accuracy: 0.3125
# Current train average loss: 0.061869122087955475
#
# Current batch: 600
# Current train accuracy: 0.40625
# Current train average loss: 0.0554937943816185
#
# Current batch: 700
# Current train accuracy: 0.46875
# Current train average loss: 0.04970534145832062
#
# Current batch: 800
# Current train accuracy: 0.40625
# Current train average loss: 0.054232239723205566
#
# Current batch: 900
# Current train accuracy: 0.4375
# Current train average loss: 0.05146906152367592
#
# Current batch: 1000
# Current train accuracy: 0.25
# Current train average loss: 0.05370531976222992
#
# Current batch: 1100
# Current train accuracy: 0.40625
# Current train average loss: 0.0540386363863945
#
# Current batch: 1200
# Current train accuracy: 0.3125
# Current train average loss: 0.053603269159793854
#
# Current batch: 1300
# Current train accuracy: 0.28125
# Current train average loss: 0.05991619452834129
#
# Current batch: 1400
# Current train accuracy: 0.46875
# Current train average loss: 0.053218550980091095
#
# Current batch: 1500
# Current train accuracy: 0.40625
# Current train average loss: 0.05235796794295311
#
# Train accuarcy: 38.776
# Train average loss: 0.053052973465919494
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 38.81
# Test average loss: 0.05195881291627884
# Model Saved
#
# Time elapsed: 1914.4982063770294
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current train accuracy: 0.40625
# Current train average loss: 0.052610091865062714
#
# Current batch: 100
# Current train accuracy: 0.34375
# Current train average loss: 0.0520155131816864
#
# Current batch: 200
# Current train accuracy: 0.625
# Current train average loss: 0.04467843100428581
#
# Current batch: 300
# Current train accuracy: 0.21875
# Current train average loss: 0.05802392214536667
#
# Current batch: 400
# Current train accuracy: 0.3125
# Current train average loss: 0.05600568652153015
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.0535450279712677
#
# Current batch: 600
# Current train accuracy: 0.5625
# Current train average loss: 0.04199359938502312
#
# Current batch: 700
# Current train accuracy: 0.34375
# Current train average loss: 0.062280282378196716
#
# Current batch: 800
# Current train accuracy: 0.375
# Current train average loss: 0.04680875316262245
#
# Current batch: 900
# Current train accuracy: 0.46875
# Current train average loss: 0.051722001284360886
#
# Current batch: 1000
# Current train accuracy: 0.40625
# Current train average loss: 0.04775416851043701
#
# Current batch: 1100
# Current train accuracy: 0.34375
# Current train average loss: 0.05714862793684006
#
# Current batch: 1200
# Current train accuracy: 0.40625
# Current train average loss: 0.04802738130092621
#
# Current batch: 1300
# Current train accuracy: 0.46875
# Current train average loss: 0.04930973798036575
#
# Current batch: 1400
# Current train accuracy: 0.34375
# Current train average loss: 0.05417366325855255
#
# Current batch: 1500
# Current train accuracy: 0.28125
# Current train average loss: 0.05528227612376213
#
# Train accuarcy: 38.714
# Train average loss: 0.05273415486097336
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 41.05
# Test average loss: 0.05099918781518936
# Model Saved
#
# Time elapsed: 2112.975320339203
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current train accuracy: 0.4375
# Current train average loss: 0.04566653072834015
#
# Current batch: 100
# Current train accuracy: 0.21875
# Current train average loss: 0.0679730698466301
#
# Current batch: 200
# Current train accuracy: 0.28125
# Current train average loss: 0.05395713821053505
#
# Current batch: 300
# Current train accuracy: 0.28125
# Current train average loss: 0.05488910153508186
#
# Current batch: 400
# Current train accuracy: 0.4375
# Current train average loss: 0.04927497357130051
#
# Current batch: 500
# Current train accuracy: 0.46875
# Current train average loss: 0.04520886018872261
#
# Current batch: 600
# Current train accuracy: 0.5625
# Current train average loss: 0.04640764743089676
#
# Current batch: 700
# Current train accuracy: 0.28125
# Current train average loss: 0.0639597699046135
#
# Current batch: 800
# Current train accuracy: 0.34375
# Current train average loss: 0.05167536810040474
#
# Current batch: 900
# Current train accuracy: 0.5
# Current train average loss: 0.03853007033467293
#
# Current batch: 1000
# Current train accuracy: 0.4375
# Current train average loss: 0.05048371106386185
#
# Current batch: 1100
# Current train accuracy: 0.375
# Current train average loss: 0.05173536390066147
#
# Current batch: 1200
# Current train accuracy: 0.34375
# Current train average loss: 0.05184067785739899
#
# Current batch: 1300
# Current train accuracy: 0.34375
# Current train average loss: 0.045902956277132034
#
# Current batch: 1400
# Current train accuracy: 0.28125
# Current train average loss: 0.05725431069731712
#
# Current batch: 1500
# Current train accuracy: 0.46875
# Current train average loss: 0.047142721712589264
#
# Train accuarcy: 40.578
# Train average loss: 0.05121802061319351
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 43.45
# Test average loss: 0.04837110426425934
# Model Saved
#
# Time elapsed: 2309.1155948638916
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current train accuracy: 0.4375
# Current train average loss: 0.046831510961055756
#
# Current batch: 100
# Current train accuracy: 0.40625
# Current train average loss: 0.044929973781108856
#
# Current batch: 200
# Current train accuracy: 0.40625
# Current train average loss: 0.06338021159172058
#
# Current batch: 300
# Current train accuracy: 0.28125
# Current train average loss: 0.05968541279435158
#
# Current batch: 400
# Current train accuracy: 0.3125
# Current train average loss: 0.06228194013237953
#
# Current batch: 500
# Current train accuracy: 0.46875
# Current train average loss: 0.04997652769088745
#
# Current batch: 600
# Current train accuracy: 0.4375
# Current train average loss: 0.05076223239302635
#
# Current batch: 700
# Current train accuracy: 0.1875
# Current train average loss: 0.07231826335191727
#
# Current batch: 800
# Current train accuracy: 0.46875
# Current train average loss: 0.0443914495408535
#
# Current batch: 900
# Current train accuracy: 0.3125
# Current train average loss: 0.05657312273979187
#
# Current batch: 1000
# Current train accuracy: 0.375
# Current train average loss: 0.0497603714466095
#
# Current batch: 1100
# Current train accuracy: 0.4375
# Current train average loss: 0.045523397624492645
#
# Current batch: 1200
# Current train accuracy: 0.34375
# Current train average loss: 0.04747593775391579
#
# Current batch: 1300
# Current train accuracy: 0.5
# Current train average loss: 0.03975031152367592
#
# Current batch: 1400
# Current train accuracy: 0.46875
# Current train average loss: 0.04375183582305908
#
# Current batch: 1500
# Current train accuracy: 0.375
# Current train average loss: 0.05402881279587746
#
# Train accuarcy: 39.906
# Train average loss: 0.051913897953033444
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 34.68
# Test average loss: 0.060121228325366975
# Model Saved
#
# Time elapsed: 2505.4804303646088
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current train accuracy: 0.375
# Current train average loss: 0.055358391255140305
#
# Current batch: 100
# Current train accuracy: 0.25
# Current train average loss: 0.05798960477113724
#
# Current batch: 200
# Current train accuracy: 0.3125
# Current train average loss: 0.05811409279704094
#
# Current batch: 300
# Current train accuracy: 0.34375
# Current train average loss: 0.055618710815906525
#
# Current batch: 400
# Current train accuracy: 0.375
# Current train average loss: 0.05102132633328438
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.05333602800965309
#
# Current batch: 600
# Current train accuracy: 0.375
# Current train average loss: 0.048335153609514236
#
# Current batch: 700
# Current train accuracy: 0.34375
# Current train average loss: 0.049692925065755844
#
# Current batch: 800
# Current train accuracy: 0.21875
# Current train average loss: 0.05919938534498215
#
# Current batch: 900
# Current train accuracy: 0.46875
# Current train average loss: 0.05057796463370323
#
# Current batch: 1000
# Current train accuracy: 0.59375
# Current train average loss: 0.039894890040159225
#
# Current batch: 1100
# Current train accuracy: 0.34375
# Current train average loss: 0.050250016152858734
# Current batch: 1200
# Current train accuracy: 0.5625
# Current train average loss: 0.041670266538858414
#
# Current batch: 1300
# Current train accuracy: 0.375
# Current train average loss: 0.047378893941640854
#
# Current batch: 1400
# Current train accuracy: 0.34375
# Current train average loss: 0.04939613491296768
#
# Current batch: 1500
# Current train accuracy: 0.46875
# Current train average loss: 0.04821382835507393
#
# Train accuarcy: 39.502
# Train average loss: 0.05221077577352524
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 42.52
# Test average loss: 0.05036243889331818
# Model Saved
#
# Time elapsed: 2702.9248135089874
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current train accuracy: 0.5
# Current train average loss: 0.04573345184326172
#
# Current batch: 100
# Current train accuracy: 0.40625
# Current train average loss: 0.05859464034438133
#
# Current batch: 200
# Current train accuracy: 0.25
# Current train average loss: 0.053075723350048065
#
# Current batch: 300
# Current train accuracy: 0.40625
# Current train average loss: 0.05085001885890961
#
# Current batch: 400
# Current train accuracy: 0.375
# Current train average loss: 0.04914122074842453
#
# Current batch: 500
# Current train accuracy: 0.4375
# Current train average loss: 0.048605043441057205
#
# Current batch: 600
# Current train accuracy: 0.21875
# Current train average loss: 0.057145245373249054
#
# Current batch: 700
# Current train accuracy: 0.5
# Current train average loss: 0.04581978917121887
#
# Current batch: 800
# Current train accuracy: 0.46875
# Current train average loss: 0.04985402524471283
#
# Current batch: 900
# Current train accuracy: 0.21875
# Current train average loss: 0.062312860041856766
#
# Current batch: 1000
# Current train accuracy: 0.375
# Current train average loss: 0.05572685971856117
#
# Current batch: 1100
# Current train accuracy: 0.5
# Current train average loss: 0.04744026064872742
#
# Current batch: 1200
# Current train accuracy: 0.15625
# Current train average loss: 0.06654098629951477
#
# Current batch: 1300
# Current train accuracy: 0.4375
# Current train average loss: 0.04383208602666855
#
# Current batch: 1400
# Current train accuracy: 0.375
# Current train average loss: 0.050837062299251556
#
# Current batch: 1500
# Current train accuracy: 0.625
# Current train average loss: 0.03701113536953926
#
# Train accuarcy: 39.762
# Train average loss: 0.052017271453142166
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 44.08
# Test average loss: 0.04952934654951095
# Model Saved
#
# Time elapsed: 2901.109444141388
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current train accuracy: 0.53125
# Current train average loss: 0.04177512601017952
#
# Current batch: 100
# Current train accuracy: 0.4375
# Current train average loss: 0.054831456393003464
#
# Current batch: 200
# Current train accuracy: 0.40625
# Current train average loss: 0.05448088422417641
#
# Current batch: 300
# Current train accuracy: 0.46875
# Current train average loss: 0.049817249178886414
#
# Current batch: 400
# Current train accuracy: 0.53125
# Current train average loss: 0.054453860968351364
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.049314945936203
#
# Current batch: 600
# Current train accuracy: 0.28125
# Current train average loss: 0.05521313101053238
#
# Current batch: 700
# Current train accuracy: 0.5
# Current train average loss: 0.04680631309747696
#
# Current batch: 800
# Current train accuracy: 0.40625
# Current train average loss: 0.05135483667254448
#
# Current batch: 900
# Current train accuracy: 0.59375
# Current train average loss: 0.03835707902908325
#
# Current batch: 1000
# Current train accuracy: 0.53125
# Current train average loss: 0.041831571608781815
#
# Current batch: 1100
# Current train accuracy: 0.4375
# Current train average loss: 0.05728021636605263
#
# Current batch: 1200
# Current train accuracy: 0.125
# Current train average loss: 0.05489804595708847
#
# Current batch: 1300
# Current train accuracy: 0.1875
# Current train average loss: 0.06820906698703766
#
# Current batch: 1400
# Current train accuracy: 0.25
# Current train average loss: 0.06221488118171692
#
# Current batch: 1500
# Current train accuracy: 0.21875
# Current train average loss: 0.061310261487960815
#
# Train accuarcy: 39.312
# Train average loss: 0.05201692337989807
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 35.55
# Test average loss: 0.053286902582645415
# Model Saved
#
# Time elapsed: 3098.9535245895386
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current train accuracy: 0.1875
# Current train average loss: 0.06141381338238716
#
# Current batch: 100
# Current train accuracy: 0.21875
# Current train average loss: 0.062383830547332764
#
# Current batch: 200
# Current train accuracy: 0.28125
# Current train average loss: 0.055034708231687546
#
# Current batch: 300
# Current train accuracy: 0.375
# Current train average loss: 0.05404073745012283
#
# Current batch: 400
# Current train accuracy: 0.28125
# Current train average loss: 0.051814038306474686
#
# Current batch: 500
# Current train accuracy: 0.375
# Current train average loss: 0.05020170286297798
#
# Current batch: 600
# Current train accuracy: 0.3125
# Current train average loss: 0.0528109110891819
#
# Current batch: 700
# Current train accuracy: 0.21875
# Current train average loss: 0.0563715323805809
#
# Current batch: 800
# Current train accuracy: 0.40625
# Current train average loss: 0.051731932908296585
#
# Current batch: 900
# Current train accuracy: 0.34375
# Current train average loss: 0.05416801571846008
#
# Current batch: 1000
# Current train accuracy: 0.25
# Current train average loss: 0.062176477164030075
#
# Current batch: 1100
# Current train accuracy: 0.28125
# Current train average loss: 0.05715492367744446
#
# Current batch: 1200
# Current train accuracy: 0.28125
# Current train average loss: 0.05952678620815277
#
# Current batch: 1300
# Current train accuracy: 0.1875
# Current train average loss: 0.06481984257698059
#
# Current batch: 1400
# Current train accuracy: 0.1875
# Current train average loss: 0.06881130486726761
#
# Current batch: 1500
# Current train accuracy: 0.21875
# Current train average loss: 0.06162923574447632
#
# Train accuarcy: 31.444
# Train average loss: 0.05760013137102127
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 24.38
# Test average loss: 0.06076643149852753
# Model Saved
#
# Time elapsed: 3296.691705226898
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current train accuracy: 0.15625
# Current train average loss: 0.06451791524887085
#
# Current batch: 100
# Current train accuracy: 0.125
# Current train average loss: 0.0623490996658802
#
# Current batch: 200
# Current train accuracy: 0.40625
# Current train average loss: 0.0485294833779335
#
# Current batch: 300
# Current train accuracy: 0.3125
# Current train average loss: 0.05117694288492203
#
# Current batch: 400
# Current train accuracy: 0.375
# Current train average loss: 0.051938604563474655
#
# Current batch: 500
# Current train accuracy: 0.40625
# Current train average loss: 0.04791608452796936
#
# Current batch: 600
# Current train accuracy: 0.3125
# Current train average loss: 0.058255162090063095
#
# Current batch: 700
# Current train accuracy: 0.34375
# Current train average loss: 0.060313161462545395
#
# Current batch: 800
# Current train accuracy: 0.375
# Current train average loss: 0.04983403533697128
#
# Current batch: 900
# Current train accuracy: 0.34375
# Current train average loss: 0.05102691054344177
#
# Current batch: 1000
# Current train accuracy: 0.3125
# Current train average loss: 0.0544888898730278
#
# Current batch: 1100
# Current train accuracy: 0.34375
# Current train average loss: 0.05360639467835426
#
# Current batch: 1200
# Current train accuracy: 0.1875
# Current train average loss: 0.061845310032367706
#
# Current batch: 1300
# Current train accuracy: 0.375
# Current train average loss: 0.057469967752695084
#
# Current batch: 1400
# Current train accuracy: 0.34375
# Current train average loss: 0.05553760752081871
#
# Current batch: 1500
# Current train accuracy: 0.4375
# Current train average loss: 0.049478501081466675
#
# Train accuarcy: 31.686
# Train average loss: 0.05661724982976914
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 31.72
# Test average loss: 0.054875818312168125
# Model Saved
#
# Time elapsed: 3493.449257850647
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current train accuracy: 0.375
# Current train average loss: 0.048200104385614395
#
# Current batch: 100
# Current train accuracy: 0.40625
# Current train average loss: 0.053678885102272034
#
# Current batch: 200
# Current train accuracy: 0.53125
# Current train average loss: 0.04948287457227707
#
# Current batch: 300
# Current train accuracy: 0.25
# Current train average loss: 0.06045202910900116
# Current batch: 400
# Current train accuracy: 0.09375
# Current train average loss: 0.07261548936367035
#
# Current batch: 500
# Current train accuracy: 0.09375
# Current train average loss: 0.07195505499839783
#
# Current batch: 600
# Current train accuracy: 0.0625
# Current train average loss: 0.07227663695812225
#
# Current batch: 700
# Current train accuracy: 0.09375
# Current train average loss: 0.07251587510108948
#
# Current batch: 800
# Current train accuracy: 0.09375
# Current train average loss: 0.07203119993209839
#
# Current batch: 900
# Current train accuracy: 0.03125
# Current train average loss: 0.07221284508705139
#
# Current batch: 1000
# Current train accuracy: 0.125
# Current train average loss: 0.07199443876743317
#
# Current batch: 1100
# Current train accuracy: 0.03125
# Current train average loss: 0.07234750688076019
#
# Current batch: 1200
# Current train accuracy: 0.125
# Current train average loss: 0.07126687467098236
#
# Current batch: 1300
# Current train accuracy: 0.03125
# Current train average loss: 0.0719938576221466
#
# Current batch: 1400
# Current train accuracy: 0.125
# Current train average loss: 0.07214565575122833
#
# Current batch: 1500
# Current train accuracy: 0.0625
# Current train average loss: 0.07197864353656769
#
# Train accuarcy: 14.14
# Train average loss: 0.06959944974660874
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.0723690775156021
# Model Saved
#
# Time elapsed: 3689.592493057251
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current train accuracy: 0.125
# Current train average loss: 0.07238230109214783
#
# Current batch: 100
# Current train accuracy: 0.0625
# Current train average loss: 0.07136297971010208
#
# Current batch: 200
# Current train accuracy: 0.09375
# Current train average loss: 0.07199687510728836
#
# Current batch: 300
# Current train accuracy: 0.0
# Current train average loss: 0.07274830341339111
#
# Current batch: 400
# Current train accuracy: 0.1875
# Current train average loss: 0.0712490975856781
#
# Current batch: 500
# Current train accuracy: 0.0625
# Current train average loss: 0.07193747907876968
#
# Current batch: 600
# Current train accuracy: 0.125
# Current train average loss: 0.07219308614730835
#
# Current batch: 700
# Current train accuracy: 0.1875
# Current train average loss: 0.07143927365541458
#
# Current batch: 800
# Current train accuracy: 0.125
# Current train average loss: 0.07205073535442352
#
# Current batch: 900
# Current train accuracy: 0.0625
# Current train average loss: 0.07241377234458923
#
# Current batch: 1000
# Current train accuracy: 0.125
# Current train average loss: 0.07154352962970734
#
# Current batch: 1100
# Current train accuracy: 0.125
# Current train average loss: 0.07139535993337631
#
# Current batch: 1200
# Current train accuracy: 0.1875
# Current train average loss: 0.07152765244245529
#
# Current batch: 1300
# Current train accuracy: 0.21875
# Current train average loss: 0.07073278725147247
#
# Current batch: 1400
# Current train accuracy: 0.1875
# Current train average loss: 0.07120209187269211
#
# Current batch: 1500
# Current train accuracy: 0.15625
# Current train average loss: 0.07203397899866104
#
# Train accuarcy: 10.118
# Train average loss: 0.0721986248254776
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.07236474006175996
# Model Saved
#
# Time elapsed: 3884.173924446106
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current train accuracy: 0.09375
# Current train average loss: 0.0734209269285202
#
# Current batch: 100
# Current train accuracy: 0.0625
# Current train average loss: 0.0720541849732399
#
# Current batch: 200
# Current train accuracy: 0.09375
# Current train average loss: 0.07152728736400604
#
# Current batch: 300
# Current train accuracy: 0.125
# Current train average loss: 0.07100451737642288
#
# Current batch: 400
# Current train accuracy: 0.09375
# Current train average loss: 0.07337340712547302
#
# Current batch: 500
# Current train accuracy: 0.03125
# Current train average loss: 0.07339846342802048
#
# Current batch: 600
# Current train accuracy: 0.15625
# Current train average loss: 0.07211998105049133
#
# Current batch: 700
# Current train accuracy: 0.0625
# Current train average loss: 0.07246363162994385
#
# Current batch: 800
# Current train accuracy: 0.09375
# Current train average loss: 0.07210276275873184
#
# Current batch: 900
# Current train accuracy: 0.1875
# Current train average loss: 0.07092120498418808
#
# Current batch: 1000
# Current train accuracy: 0.09375
# Current train average loss: 0.07193612307310104
#
# Current batch: 1100
# Current train accuracy: 0.21875
# Current train average loss: 0.07171506434679031
#
# Current batch: 1200
# Current train accuracy: 0.03125
# Current train average loss: 0.07285255938768387
#
# Current batch: 1300
# Current train accuracy: 0.125
# Current train average loss: 0.07140742987394333
#
# Current batch: 1400
# Current train accuracy: 0.09375
# Current train average loss: 0.07149301469326019
#
# Current batch: 1500
# Current train accuracy: 0.0
# Current train average loss: 0.07286608219146729
#
# Train accuarcy: 10.07
# Train average loss: 0.07219211436271668
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.0722968918800354
# Model Saved
#
# Time elapsed: 4077.4179871082306
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current train accuracy: 0.125
# Current train average loss: 0.07188818603754044
#
# Current batch: 100
# Current train accuracy: 0.0625
# Current train average loss: 0.07222779840230942
#
# Current batch: 200
# Current train accuracy: 0.0625
# Current train average loss: 0.07404614239931107
#
# Current batch: 300
# Current train accuracy: 0.125
# Current train average loss: 0.07243038713932037
#
# Current batch: 400
# Current train accuracy: 0.125
# Current train average loss: 0.0716431587934494
#
# Current batch: 500
# Current train accuracy: 0.0625
# Current train average loss: 0.07276526838541031
#
# Current batch: 600
# Current train accuracy: 0.21875
# Current train average loss: 0.07138938456773758
#
# Current batch: 700
# Current train accuracy: 0.09375
# Current train average loss: 0.07151210308074951
#
# Current batch: 800
# Current train accuracy: 0.125
# Current train average loss: 0.07189352065324783
#
# Current batch: 900
# Current train accuracy: 0.03125
# Current train average loss: 0.0729798823595047
#
# Current batch: 1000
# Current train accuracy: 0.0625
# Current train average loss: 0.07172369211912155
#
# Current batch: 1100
# Current train accuracy: 0.09375
# Current train average loss: 0.07273881882429123
#
# Current batch: 1200
# Current train accuracy: 0.125
# Current train average loss: 0.0710250660777092
#
# Current batch: 1300
# Current train accuracy: 0.0625
# Current train average loss: 0.07242037355899811
#
# Current batch: 1400
# Current train accuracy: 0.0625
# Current train average loss: 0.07236240059137344
#
# Current batch: 1500
# Current train accuracy: 0.125
# Current train average loss: 0.07156923413276672
#
# Train accuarcy: 10.016
# Train average loss: 0.07219861085891724
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.07225312139987945
# Model Saved
#
# Time elapsed: 4271.324334144592
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current train accuracy: 0.15625
# Current train average loss: 0.0717025026679039
#
# Current batch: 100
# Current train accuracy: 0.0625
# Current train average loss: 0.07214672863483429
#
# Current batch: 200
# Current train accuracy: 0.125
# Current train average loss: 0.07204394787549973
#
# Current batch: 300
# Current train accuracy: 0.09375
# Current train average loss: 0.07235034555196762
#
# Current batch: 400
# Current train accuracy: 0.125
# Current train average loss: 0.071864053606987
#
# Current batch: 500
# Current train accuracy: 0.03125
# Current train average loss: 0.07208974659442902
#
# Current batch: 600
# Current train accuracy: 0.09375
# Current train average loss: 0.07213811576366425
#
# Current batch: 700
# Current train accuracy: 0.0625
# Current train average loss: 0.07345619797706604
#
# Current batch: 800
# Current train accuracy: 0.03125
# Current train average loss: 0.07233460247516632
#
# Current batch: 900
# Current train accuracy: 0.0625
# Current train average loss: 0.07286030799150467
#
# Current batch: 1000
# Current train accuracy: 0.03125
# Current train average loss: 0.07351559400558472
#
# Current batch: 1100
# Current train accuracy: 0.1875
# Current train average loss: 0.07123864442110062
#
# Current batch: 1200
# Current train accuracy: 0.09375
# Current train average loss: 0.07274895161390305
#
# Current batch: 1300
# Current train accuracy: 0.15625
# Current train average loss: 0.07269113510847092
#
# Current batch: 1400
# Current train accuracy: 0.1875
# Current train average loss: 0.07133673131465912
# Current batch: 1500
# Current train accuracy: 0.09375
# Current train average loss: 0.07163488864898682
#
# Train accuarcy: 9.96
# Train average loss: 0.07222316401004791
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.07221124575138092
# Model Saved
#
# Time elapsed: 4465.608151912689
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current train accuracy: 0.0625
# Current train average loss: 0.0723026692867279
#
# Current batch: 100
# Current train accuracy: 0.09375
# Current train average loss: 0.0725160762667656
#
# Current batch: 200
# Current train accuracy: 0.125
# Current train average loss: 0.07234886288642883
#
# Current batch: 300
# Current train accuracy: 0.09375
# Current train average loss: 0.07266663759946823
#
# Current batch: 400
# Current train accuracy: 0.0625
# Current train average loss: 0.0735769271850586
#
# Current batch: 500
# Current train accuracy: 0.1875
# Current train average loss: 0.07279369980096817
#
# Current batch: 600
# Current train accuracy: 0.03125
# Current train average loss: 0.07222821563482285
#
# Current batch: 700
# Current train accuracy: 0.09375
# Current train average loss: 0.07208213210105896
#
# Current batch: 800
# Current train accuracy: 0.09375
# Current train average loss: 0.07201867550611496
#
# Current batch: 900
# Current train accuracy: 0.0625
# Current train average loss: 0.0726637914776802
#
# Current batch: 1000
# Current train accuracy: 0.03125
# Current train average loss: 0.07318747788667679
#
# Current batch: 1100
# Current train accuracy: 0.125
# Current train average loss: 0.07237623631954193
#
# Current batch: 1200
# Current train accuracy: 0.09375
# Current train average loss: 0.07213712483644485
#
# Current batch: 1300
# Current train accuracy: 0.125
# Current train average loss: 0.07133185118436813
#
# Current batch: 1400
# Current train accuracy: 0.0
# Current train average loss: 0.07318941503763199
#
# Current batch: 1500
# Current train accuracy: 0.1875
# Current train average loss: 0.07161320000886917
#
# Train accuarcy: 10.026
# Train average loss: 0.07218951271533966
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.072214084649086
# Model Saved
#
# Time elapsed: 4660.940217733383
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current train accuracy: 0.09375
# Current train average loss: 0.07178328186273575
#
# Current batch: 100
# Current train accuracy: 0.125
# Current train average loss: 0.07177505642175674
#
# Current batch: 200
# Current train accuracy: 0.09375
# Current train average loss: 0.0724349394440651
#
# Current batch: 300
# Current train accuracy: 0.15625
# Current train average loss: 0.07117900252342224
#
# Current batch: 400
# Current train accuracy: 0.125
# Current train average loss: 0.07161223143339157
#
# Current batch: 500
# Current train accuracy: 0.03125
# Current train average loss: 0.072022445499897
#
# Current batch: 600
# Current train accuracy: 0.09375
# Current train average loss: 0.07219710201025009
#
# Current batch: 700
# Current train accuracy: 0.1875
# Current train average loss: 0.07208847999572754
#
# Current batch: 800
# Current train accuracy: 0.125
# Current train average loss: 0.07262697070837021
#
# Current batch: 900
# Current train accuracy: 0.09375
# Current train average loss: 0.07217134535312653
#
# Current batch: 1000
# Current train accuracy: 0.03125
# Current train average loss: 0.07279035449028015
#
# Current batch: 1100
# Current train accuracy: 0.125
# Current train average loss: 0.07147368043661118
#
# Current batch: 1200
# Current train accuracy: 0.1875
# Current train average loss: 0.07136335223913193
#
# Current batch: 1300
# Current train accuracy: 0.03125
# Current train average loss: 0.07257745414972305
#
# Current batch: 1400
# Current train accuracy: 0.21875
# Current train average loss: 0.07148949056863785
#
# Current batch: 1500
# Current train accuracy: 0.0625
# Current train average loss: 0.07214391231536865
#
# Train accuarcy: 9.768
# Train average loss: 0.07220744451999664
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 10.0
# Test average loss: 0.07227628297805787
# Model Saved
#
# Time elapsed: 4856.092870473862
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current train accuracy: 0.21875
# Current train average loss: 0.0709058865904808
#
# Current batch: 100
# Current train accuracy: 0.09375
# Current train average loss: 0.07280397415161133
#
# Current batch: 200
# Current train accuracy: 0.0625
# Current train average loss: 0.0731448233127594
#
# Current batch: 300
# Current train accuracy: 0.09375
# Current train average loss: 0.07118207216262817
#
# Current batch: 400
# Current train accuracy: 0.125
# Current train average loss: 0.07235996425151825
#
# Current batch: 500
# Current train accuracy: 0.125
# Current train average loss: 0.07179734110832214
#
# Current batch: 600
# Current train accuracy: 0.0625
# Current train average loss: 0.07449156045913696
#
# Current batch: 700
# Current train accuracy: 0.1875
# Current train average loss: 0.07198212295770645
#
# Current batch: 800
# Current train accuracy: 0.09375
# Current train average loss: 0.07175745069980621
#
# Current batch: 900
# Current train accuracy: 0.0
# Current train average loss: 0.07256525754928589
#
# Current batch: 1000
# Current train accuracy: 0.125
# Current train average loss: 0.07133793085813522
#
# Current batch: 1100
# Current train accuracy: 0.125
# Current train average loss: 0.07171068340539932
#
# Current batch: 1200
# Current train accuracy: 0.125
# Current train average loss: 0.07210587710142136
#
# Current batch: 1300
# Current train accuracy: 0.15625
# Current train average loss: 0.07168146222829819
#
# Current batch: 1400
# Current train accuracy: 0.09375
# Current train average loss: 0.07279356569051743
#
# Current batch: 1500
# Current train accuracy: 0.09375
# Current train average loss: 0.07242099195718765
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1cd2f76de613> in <module>
#       3 for epoch in range(0, 60):
#       4     #adjust_learning_rate(optimizer, epoch)
# ----> 5     train(epoch)
#       6     test(epoch)
#       7     print('\nTime elapsed:', time.time() - start_time)
#
# <ipython-input-6-a3db214a876e> in train(epoch)
#      20         optimizer.step()
#      21
# ---> 22         train_loss += loss.item()
#      23         _, prediction = outputs.max(1)
#      24
#
# KeyboardInterrupt:

# %%
df_train_l = pd.DataFrame(train_losses, columns = ['train_losses'])
df_train_l.plot(color = "#ff0000")
plt.plot(df_train_l, marker = '*', color = 'r')
plt.show()

# %%
df_train_a = pd.DataFrame(train_accuracy, columns = ['train_accuracy'])
df_train_a.plot(color = "#ff1111")
plt.plot(df_train_a, marker = '.', color = 'b')
plt.show()

# %%
df_test_l = pd.DataFrame(test_losses, columns = ['test_losses'])
df_test_l.plot(color = "#ff0000")
plt.plot(df_test_l, marker = '*', color = 'r')
plt.show()

# %%
df_test_a = pd.DataFrame(test_accuracy, columns = ['test_accuracy'])
df_test_a.plot(color = "#ff0000")
plt.plot(df_test_a, marker = '*', color = 'r')
plt.show()
