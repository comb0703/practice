# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

# %%
#GPU
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
#dataset
transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='./data',
                                        train=True,
                                        download=True,
                                        transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data',
                                       train=False,
                                       download=True,
                                       transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset,
                                          batch_size=128,
                                          shuffle=True,
                                          num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset,
                                         batch_size=128,
                                         shuffle=False,
                                         num_workers=4)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) 
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) 
        self.shortcut = nn.Sequential() 
        if stride != 1: 
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) 
        out = F.relu(out)
        return out


# ResNet class
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, 2, stride=1)
        self.layer2 = self._make_layer(block, 34, 2, stride=2)
        self.layer3 = self._make_layer(block, 64, 2, stride=2)
        self.linear = nn.Linear(64, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(BasicBlock(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet20():
    return ResNet(BasicBlock, [3, 3, 3])
def ResNet32():
    return ResNet(BasicBlock, [5, 5, 5])
def ResNet44():
    return ResNet(BasicBlock, [7, 7, 7])
def ResNet56():
    return ResNet(BasicBlock, [9, 9, 9])

# %%
#criterion,optimizer
file_name = 'resnet44_cifar10.pt'

net = ResNet44()
net = net.to(device)

learning_rate = 0.1
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0001)

# %%
#schedular
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 80:
        lr /= 10
    if epoch >= 120:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %%
# train, test function
def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 128 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')

# %%
for epoch in range(0, 160):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current benign train accuracy: 0.09375
# Current benign train loss: 2.3872923851013184
#
# Current batch: 128
# Current benign train accuracy: 0.3984375
# Current benign train loss: 1.6898159980773926
#
# Current batch: 256
# Current benign train accuracy: 0.4375
# Current benign train loss: 1.4282162189483643
#
# Current batch: 384
# Current benign train accuracy: 0.5703125
# Current benign train loss: 1.1736644506454468
#
# Total benign train accuarcy: 39.876
# Total benign train loss: 630.0134568214417
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 45.78
# Test average loss: 0.012454202163219451
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.2137264013290405
#
# Current batch: 128
# Current benign train accuracy: 0.515625
# Current benign train loss: 1.2177356481552124
#
# Current batch: 256
# Current benign train accuracy: 0.578125
# Current benign train loss: 1.0767384767532349
#
# Current batch: 384
# Current benign train accuracy: 0.6484375
# Current benign train loss: 1.0404905080795288
#
# Total benign train accuarcy: 60.398
# Total benign train loss: 429.7667273879051
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 61.21
# Test average loss: 0.008717764681577683
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6875
# Current benign train loss: 0.827681839466095
#
# Current batch: 128
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.8917515277862549
#
# Current batch: 256
# Current benign train accuracy: 0.7109375
# Current benign train loss: 0.7702167630195618
#
# Current batch: 384
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6430913209915161
#
# Total benign train accuarcy: 68.324
# Total benign train loss: 348.3764942884445
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 64.72
# Test average loss: 0.008101614564657212
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.7394923567771912
#
# Current batch: 128
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8756181597709656
#
# Current batch: 256
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7817930579185486
#
# Current batch: 384
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6788126826286316
#
# Total benign train accuarcy: 73.112
# Total benign train loss: 296.22579312324524
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 69.35
# Test average loss: 0.006889618462324143
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7054584622383118
#
# Current batch: 128
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.6554250121116638
#
# Current batch: 256
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5626365542411804
#
# Current batch: 384
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6708842515945435
#
# Total benign train accuarcy: 75.98
# Total benign train loss: 266.6999695301056
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 73.57
# Test average loss: 0.005864318823814392
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.5142979025840759
#
# Current batch: 128
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.6440467834472656
#
# Current batch: 256
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6261819005012512
#
# Current batch: 384
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5977955460548401
#
# Total benign train accuarcy: 78.072
# Total benign train loss: 246.38804429769516
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 75.5
# Test average loss: 0.005539858090877533
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5908369421958923
#
# Current batch: 128
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5275646448135376
#
# Current batch: 256
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.588077962398529
#
# Current batch: 384
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5223525762557983
#
# Total benign train accuarcy: 79.714
# Total benign train loss: 228.05060750246048
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 76.27
# Test average loss: 0.005330736848711968
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4730776250362396
#
# Current batch: 128
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5806576013565063
#
# Current batch: 256
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.524830162525177
#
# Current batch: 384
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5193625688552856
#
# Total benign train accuarcy: 80.854
# Total benign train loss: 217.54474058747292
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 77.2
# Test average loss: 0.005314306643605232
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.48480933904647827
#
# Current batch: 128
# Current benign train accuracy: 0.765625
# Current benign train loss: 0.6620370745658875
#
# Current batch: 256
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.6101186871528625
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.5535900592803955
#
# Total benign train accuarcy: 81.51
# Total benign train loss: 207.07089146971703
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 79.6
# Test average loss: 0.004665592628717422
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5204467177391052
#
# Current batch: 128
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.480585515499115
#
# Current batch: 256
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5942723155021667
#
# Current batch: 384
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5099149346351624
#
# Total benign train accuarcy: 82.32
# Total benign train loss: 197.96607503294945
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 79.74
# Test average loss: 0.004669608741998672
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4964187741279602
#
# Current batch: 128
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5213524103164673
#
# Current batch: 256
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.6218472719192505
#
# Current batch: 384
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5969837307929993
#
# Total benign train accuarcy: 83.328
# Total benign train loss: 188.82924270629883
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 79.76
# Test average loss: 0.004706726743280888
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4840275049209595
#
# Current batch: 128
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.47208186984062195
#
# Current batch: 256
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3837564289569855
#
# Current batch: 384
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3400767743587494
#
# Total benign train accuarcy: 83.698
# Total benign train loss: 184.03967434167862
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 79.06
# Test average loss: 0.004795481172204017
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3272731602191925
#
# Current batch: 128
# Current benign train accuracy: 0.7890625
# Current benign train loss: 0.5711652636528015
#
# Current batch: 256
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.5188245177268982
#
# Current batch: 384
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.48539412021636963
#
# Total benign train accuarcy: 84.228
# Total benign train loss: 180.03604899346828
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 77.8
# Test average loss: 0.005317314422130585
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.5250041484832764
#
# Current batch: 128
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4007684290409088
# Current batch: 256
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.49643734097480774
#
# Current batch: 384
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37144505977630615
#
# Total benign train accuarcy: 84.62
# Total benign train loss: 173.0996274650097
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 83.08
# Test average loss: 0.003918970200419426
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.42640402913093567
#
# Current batch: 128
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4810307025909424
#
# Current batch: 256
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.366132915019989
#
# Current batch: 384
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4618881344795227
#
# Total benign train accuarcy: 85.0
# Total benign train loss: 167.97856564819813
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 78.77
# Test average loss: 0.0049705470860004425
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5744519233703613
#
# Current batch: 128
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4395776093006134
#
# Current batch: 256
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.38298866152763367
#
# Current batch: 384
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.48882824182510376
#
# Total benign train accuarcy: 85.278
# Total benign train loss: 166.3900232166052
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 82.35
# Test average loss: 0.004244711390137672
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4506285786628723
#
# Current batch: 128
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.521372377872467
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3502863049507141
#
# Current batch: 384
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4294920265674591
#
# Total benign train accuarcy: 85.564
# Total benign train loss: 161.64673200249672
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 83.07
# Test average loss: 0.0038587978571653367
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3150809407234192
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.34226658940315247
#
# Current batch: 256
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4298522174358368
#
# Current batch: 384
# Current benign train accuracy: 0.8125
# Current benign train loss: 0.49499139189720154
#
# Total benign train accuarcy: 86.106
# Total benign train loss: 156.67336167395115
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 82.12
# Test average loss: 0.0041726851522922515
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.25877293944358826
#
# Current batch: 128
# Current benign train accuracy: 0.875
# Current benign train loss: 0.42725878953933716
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2782445251941681
#
# Current batch: 384
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.44619500637054443
#
# Total benign train accuarcy: 86.322
# Total benign train loss: 154.92382107675076
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 83.46
# Test average loss: 0.003870802591741085
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3895544111728668
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.34498074650764465
#
# Current batch: 256
# Current benign train accuracy: 0.875
# Current benign train loss: 0.38298627734184265
#
# Current batch: 384
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.416782021522522
#
# Total benign train accuarcy: 86.724
# Total benign train loss: 149.34133744239807
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 82.43
# Test average loss: 0.004307542270421982
# Model Saved!
#
# [ Train epoch: 20 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.24862967431545258
#
# Current batch: 128
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.4168517291545868
#
# Current batch: 256
# Current benign train accuracy: 0.875
# Current benign train loss: 0.31451892852783203
#
# Current batch: 384
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37552064657211304
#
# Total benign train accuarcy: 86.782
# Total benign train loss: 148.59075172245502
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 80.26
# Test average loss: 0.004658822813630104
# Model Saved!
#
# [ Train epoch: 21 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4140098989009857
#
# Current batch: 128
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.42651867866516113
#
# Current batch: 256
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.40063416957855225
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3254430890083313
#
# Total benign train accuarcy: 86.938
# Total benign train loss: 148.2051606029272
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 83.17
# Test average loss: 0.004000264073908329
# Model Saved!
#
# [ Train epoch: 22 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.308683842420578
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3162979781627655
#
# Current batch: 256
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4383256137371063
#
# Current batch: 384
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.32271838188171387
#
# Total benign train accuarcy: 87.316
# Total benign train loss: 141.86239705979824
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 82.32
# Test average loss: 0.004208742389082909
# Model Saved!
#
# [ Train epoch: 23 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3380460739135742
#
# Current batch: 128
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2517078220844269
#
# Current batch: 256
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3946627974510193
#
# Current batch: 384
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.40700456500053406
#
# Total benign train accuarcy: 87.244
# Total benign train loss: 142.11560648679733
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 82.12
# Test average loss: 0.004317389714717865
# Model Saved!
#
# [ Train epoch: 24 ]
#
# Current batch: 0
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.46862098574638367
#
# Current batch: 128
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.37643522024154663
#
# Current batch: 256
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3871139883995056
#
# Current batch: 384
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.37972491979599
#
# Total benign train accuarcy: 87.192
# Total benign train loss: 143.47342185676098
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 83.58
# Test average loss: 0.0037745276570320127
# Model Saved!
#
# [ Train epoch: 25 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23571087419986725
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.29701101779937744
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.30262231826782227
#
# Current batch: 384
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.3962506055831909
#
# Total benign train accuarcy: 87.812
# Total benign train loss: 138.0479801595211
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 83.03
# Test average loss: 0.0040401822060346605
# Model Saved!
#
# [ Train epoch: 26 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3549666106700897
#
# Current batch: 128
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.520455539226532
#
# Current batch: 256
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.5181505084037781
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.29868337512016296
# Total benign train accuarcy: 87.736
# Total benign train loss: 137.89911152422428
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 82.06
# Test average loss: 0.004291072851419449
# Model Saved!
#
# [ Train epoch: 27 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2819284498691559
#
# Current batch: 128
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.29292941093444824
#
# Current batch: 256
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.40012186765670776
#
# Current batch: 384
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4565129280090332
#
# Total benign train accuarcy: 87.888
# Total benign train loss: 135.7430645376444
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 84.37
# Test average loss: 0.0035323432117700575
# Model Saved!
#
# [ Train epoch: 28 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3715158998966217
#
# Current batch: 128
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.384680837392807
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3279697597026825
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.25233471393585205
#
# Total benign train accuarcy: 88.214
# Total benign train loss: 133.55221366882324
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 84.8
# Test average loss: 0.0035718510925769804
# Model Saved!
#
# [ Train epoch: 29 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2905559539794922
#
# Current batch: 128
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1721958965063095
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.27357903122901917
#
# Current batch: 384
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21534129977226257
#
# Total benign train accuarcy: 88.106
# Total benign train loss: 132.6618590950966
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 81.5
# Test average loss: 0.00466288925409317
# Model Saved!
#
# [ Train epoch: 30 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.38228628039360046
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2389979213476181
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3382195830345154
#
# Current batch: 384
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21472038328647614
#
# Total benign train accuarcy: 88.134
# Total benign train loss: 131.669286981225
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 84.37
# Test average loss: 0.003796185936033726
# Model Saved!
#
# [ Train epoch: 31 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.28530752658843994
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.28814491629600525
#
# Current batch: 256
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.44659608602523804
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.27890634536743164
#
# Total benign train accuarcy: 88.104
# Total benign train loss: 132.0588872730732
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 84.25
# Test average loss: 0.003651242098212242
# Model Saved!
#
# [ Train epoch: 32 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3562639057636261
#
# Current batch: 128
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3758107125759125
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.33314865827560425
#
# Current batch: 384
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4164045453071594
#
# Total benign train accuarcy: 88.408
# Total benign train loss: 130.1236544251442
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 83.38
# Test average loss: 0.0039859125852584835
# Model Saved!
#
# [ Train epoch: 33 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.28235235810279846
#
# Current batch: 128
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.32864663004875183
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2759056091308594
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3516812026500702
#
# Total benign train accuarcy: 88.456
# Total benign train loss: 127.61486884951591
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 81.46
# Test average loss: 0.004558637720346451
# Model Saved!
#
# [ Train epoch: 34 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.32976093888282776
#
# Current batch: 128
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3896336257457733
#
# Current batch: 256
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.32810667157173157
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3081282675266266
#
# Total benign train accuarcy: 88.78
# Total benign train loss: 127.24176043272018
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 84.26
# Test average loss: 0.0036060051172971726
# Model Saved!
#
# [ Train epoch: 35 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24559420347213745
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2616289556026459
#
# Current batch: 256
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.29075101017951965
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.30790820717811584
#
# Total benign train accuarcy: 88.644
# Total benign train loss: 126.9308458417654
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 83.17
# Test average loss: 0.00396705687046051
# Model Saved!
#
# [ Train epoch: 36 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2687017023563385
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3663720190525055
#
# Current batch: 256
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.3526582717895508
#
# Current batch: 384
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.48609915375709534
#
# Total benign train accuarcy: 88.942
# Total benign train loss: 123.99323470890522
#
# [ Test epoch: 36 ]
#
# Test accuarcy: 84.06
# Test average loss: 0.003828367131948471
# Model Saved!
#
# [ Train epoch: 37 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2481609433889389
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2817528247833252
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2915492355823517
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2659940719604492
#
# Total benign train accuarcy: 88.976
# Total benign train loss: 122.96898517012596
#
# [ Test epoch: 37 ]
#
# Test accuarcy: 82.79
# Test average loss: 0.004034630590677261
# Model Saved!
#
# [ Train epoch: 38 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2918834686279297
#
# Current batch: 128
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.35375529527664185
#
# Current batch: 256
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4803099036216736
#
# Current batch: 384
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5062993764877319
#
# Total benign train accuarcy: 89.134
# Total benign train loss: 122.46488983929157
#
# [ Test epoch: 38 ]
#
# Test accuarcy: 83.87
# Test average loss: 0.0038770937621593476
# Model Saved!
#
# [ Train epoch: 39 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.42720741033554077
#
# Current batch: 128
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.46041008830070496
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2453559935092926
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3035774528980255
#
# Total benign train accuarcy: 89.056
# Total benign train loss: 121.94801740348339
#
# [ Test epoch: 39 ]
#
# Test accuarcy: 82.98
# Test average loss: 0.0039038474559783937
# Model Saved!
#
# [ Train epoch: 40 ]
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2863515019416809
#
# Current batch: 128
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2887653708457947
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.28384849429130554
#
# Current batch: 384
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4492799639701843
#
# Total benign train accuarcy: 89.376
# Total benign train loss: 120.24563613533974
#
# [ Test epoch: 40 ]
#
# Test accuarcy: 84.3
# Test average loss: 0.003857087481021881
# Model Saved!
#
# [ Train epoch: 41 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3050512969493866
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2469753623008728
#
# Current batch: 256
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3569548428058624
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.3006887435913086
#
# Total benign train accuarcy: 89.34
# Total benign train loss: 120.75442794710398
#
# [ Test epoch: 41 ]
#
# Test accuarcy: 81.22
# Test average loss: 0.004829146039485931
# Model Saved!
#
# [ Train epoch: 42 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2874959409236908
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2710114121437073
#
# Current batch: 256
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.22952960431575775
#
# Current batch: 384
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.25947943329811096
#
# Total benign train accuarcy: 89.718
# Total benign train loss: 117.04094968736172
#
# [ Test epoch: 42 ]
#
# Test accuarcy: 85.47
# Test average loss: 0.003489874741435051
# Model Saved!
#
# [ Train epoch: 43 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.1888163685798645
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.31117475032806396
#
# Current batch: 256
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.27398183941841125
#
# Current batch: 384
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2212967425584793
#
# Total benign train accuarcy: 89.57
# Total benign train loss: 117.9797485768795
#
# [ Test epoch: 43 ]
#
# Test accuarcy: 82.32
# Test average loss: 0.004360566332936287
# Model Saved!
#
# [ Train epoch: 44 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.25544777512550354
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3091789782047272
#
# Current batch: 256
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.25361770391464233
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23551496863365173
#
# Total benign train accuarcy: 89.612
# Total benign train loss: 115.93624632060528
#
# [ Test epoch: 44 ]
#
# Test accuarcy: 85.17
# Test average loss: 0.0034581048995256424
# Model Saved!
#
# [ Train epoch: 45 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.289908766746521
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.29956576228141785
#
# Current batch: 256
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3037469983100891
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3678663671016693
#
# Total benign train accuarcy: 89.566
# Total benign train loss: 115.95939473062754
#
# [ Test epoch: 45 ]
#
# Test accuarcy: 85.05
# Test average loss: 0.003585433131456375
# Model Saved!
#
# [ Train epoch: 46 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2818707525730133
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.4199937880039215
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.37908199429512024
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24120432138442993
#
# Total benign train accuarcy: 89.64
# Total benign train loss: 115.67744169384241
#
# [ Test epoch: 46 ]
#
# Test accuarcy: 84.57
# Test average loss: 0.0038127979636192323
# Model Saved!
#
# [ Train epoch: 47 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.29032155871391296
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4431805908679962
#
# Current batch: 256
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.36063075065612793
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3307340443134308
#
# Total benign train accuarcy: 89.538
# Total benign train loss: 115.83526852726936
#
# [ Test epoch: 47 ]
#
# Test accuarcy: 83.57
# Test average loss: 0.0040466921210289
# Model Saved!
#
# [ Train epoch: 48 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2774989902973175
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.30710819363594055
#
# Current batch: 256
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4578205347061157
#
# Current batch: 384
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.3482089340686798
#
# Total benign train accuarcy: 89.572
# Total benign train loss: 115.76523958146572
#
# [ Test epoch: 48 ]
#
# Test accuarcy: 85.5
# Test average loss: 0.003388993752002716
# Model Saved!
#
# [ Train epoch: 49 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.18430857360363007
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2780170142650604
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3199351131916046
#
# Current batch: 384
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.26049888134002686
#
# Total benign train accuarcy: 89.832
# Total benign train loss: 113.99749752879143
#
# [ Test epoch: 49 ]
#
# Test accuarcy: 84.43
# Test average loss: 0.003683190470933914
# Model Saved!
#
# [ Train epoch: 50 ]
#
# Current batch: 0
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.17885172367095947
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37998688220977783
#
# Current batch: 256
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.2701273262500763
#
# Current batch: 384
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.38093236088752747
#
# Total benign train accuarcy: 89.86
# Total benign train loss: 113.6951973438263
#
# [ Test epoch: 50 ]
#
# Test accuarcy: 84.53
# Test average loss: 0.003544502928853035
# Model Saved!
#
# [ Train epoch: 51 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.34081655740737915
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3028486669063568
#
# Current batch: 256
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.32323962450027466
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3716503083705902
#
# Total benign train accuarcy: 89.916
# Total benign train loss: 112.53927548974752
#
# [ Test epoch: 51 ]
#
# Test accuarcy: 85.83
# Test average loss: 0.0033499497294425962
# Model Saved!
#
# [ Train epoch: 52 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2714499533176422
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21858783066272736
#
# Current batch: 256
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.32563844323158264
#
# Current batch: 384
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.17431752383708954
#
# Total benign train accuarcy: 89.954
# Total benign train loss: 112.39177326858044
#
# [ Test epoch: 52 ]
#
# Test accuarcy: 81.92
# Test average loss: 0.004265057647228241
# Model Saved!
#
# [ Train epoch: 53 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.26296260952949524
#
# Current batch: 128
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.2156149446964264
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.3323567807674408
#
# Current batch: 384
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3127032518386841
#
# Total benign train accuarcy: 90.1
# Total benign train loss: 112.09698347747326
#
# [ Test epoch: 53 ]
#
# Test accuarcy: 83.27
# Test average loss: 0.004004878057539463
# Model Saved!
#
# [ Train epoch: 54 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2777637839317322
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.30434226989746094
#
# Current batch: 256
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.34867045283317566
#
# Current batch: 384
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3083573877811432
#
# Total benign train accuarcy: 89.958
# Total benign train loss: 111.57555596530437
#
# [ Test epoch: 54 ]
#
# Test accuarcy: 84.61
# Test average loss: 0.003761011764407158
# Model Saved!
#
# [ Train epoch: 55 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.2214774191379547
#
# Current batch: 128
# Current benign train accuracy: 0.875
# Current benign train loss: 0.2871726453304291
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.26786473393440247
#
# Current batch: 384
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3456367552280426
#
# Total benign train accuarcy: 89.968
# Total benign train loss: 112.32851642370224
#
# [ Test epoch: 55 ]
#
# Test accuarcy: 84.25
# Test average loss: 0.0038375419110059737
# Model Saved!
#
# [ Train epoch: 56 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3155006766319275
#
# Current batch: 128
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2460070699453354
#
# Current batch: 256
# Current benign train accuracy: 0.875
# Current benign train loss: 0.35384902358055115
#
# Current batch: 384
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4037284553050995
#
# Total benign train accuarcy: 90.274
# Total benign train loss: 109.86065040528774
#
# [ Test epoch: 56 ]
#
# Test accuarcy: 85.64
# Test average loss: 0.003540198914706707
# Model Saved!
#
# [ Train epoch: 57 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2869276702404022
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.299984335899353
#
# Current batch: 256
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.34063848853111267
#
# Current batch: 384
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3035154640674591
#
# Total benign train accuarcy: 90.31
# Total benign train loss: 107.80780836194754
#
# [ Test epoch: 57 ]
#
# Test accuarcy: 85.8
# Test average loss: 0.0033718115121126177
# Model Saved!
#
# [ Train epoch: 58 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.21120628714561462
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23065772652626038
#
# Current batch: 256
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.42546412348747253
#
# Current batch: 384
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.3674548268318176
#
# Total benign train accuarcy: 90.182
# Total benign train loss: 109.94547368586063
#
# [ Test epoch: 58 ]
#
# Test accuarcy: 83.81
# Test average loss: 0.004001887655258178
# Model Saved!
#
# [ Train epoch: 59 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2298642098903656
#
# Current batch: 128
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.33742770552635193
#
# Current batch: 256
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.23505693674087524
#
# Current batch: 384
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.2509037256240845
#
# Total benign train accuarcy: 90.128
# Total benign train loss: 108.3232313990593
#
# [ Test epoch: 59 ]
#
# Test accuarcy: 84.96
# Test average loss: 0.0035409315586090086
# Model Saved!
#
# [ Train epoch: 60 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.26362723112106323
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.22780467569828033
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2923591136932373
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.27415165305137634
#
# Total benign train accuarcy: 90.33
# Total benign train loss: 108.725959867239
#
# [ Test epoch: 60 ]
#
# Test accuarcy: 84.06
# Test average loss: 0.0037211819738149645
# Model Saved!
#
# [ Train epoch: 61 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.17082054913043976
#
# Current batch: 128
# Current benign train accuracy: 0.875
# Current benign train loss: 0.43356791138648987
#
# Current batch: 256
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.33063748478889465
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.22216197848320007
#
# Total benign train accuarcy: 90.262
# Total benign train loss: 108.49818371236324
#
# [ Test epoch: 61 ]
#
# Test accuarcy: 84.29
# Test average loss: 0.0039030755460262296
# Model Saved!
#
# [ Train epoch: 62 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2846425771713257
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2515416741371155
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.25079745054244995
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2667001187801361
#
# Total benign train accuarcy: 90.284
# Total benign train loss: 108.1161445826292
#
# [ Test epoch: 62 ]
#
# Test accuarcy: 84.88
# Test average loss: 0.00358312236815691
# Model Saved!
#
# [ Train epoch: 63 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.20736180245876312
#
# Current batch: 128
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1601039320230484
#
# Current batch: 256
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.1777598112821579
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.27577903866767883
#
# Total benign train accuarcy: 90.502
# Total benign train loss: 107.31651297211647
#
# [ Test epoch: 63 ]
#
# Test accuarcy: 84.27
# Test average loss: 0.003827810298651457
# Model Saved!
#
# [ Train epoch: 64 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.37737953662872314
#
# Current batch: 128
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.22636520862579346
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.19568078219890594
#
# Current batch: 384
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3176104426383972
#
# Total benign train accuarcy: 90.638
# Total benign train loss: 104.90572291612625
#
# [ Test epoch: 64 ]
#
# Test accuarcy: 85.17
# Test average loss: 0.0035806473657488823
# Model Saved!
#
# [ Train epoch: 65 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2295209765434265
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24832618236541748
#
# Current batch: 256
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.1942068487405777
#
# Current batch: 384
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2643432021141052
#
# Total benign train accuarcy: 90.388
# Total benign train loss: 107.18893022090197
#
# [ Test epoch: 65 ]
#
# Test accuarcy: 86.1
# Test average loss: 0.003410595452785492
# Model Saved!
#
# [ Train epoch: 66 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2933040261268616
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.21052393317222595
#
# Current batch: 256
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.22832399606704712
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24722056090831757
# Total benign train accuarcy: 90.702
# Total benign train loss: 104.84268681704998
#
# [ Test epoch: 66 ]
#
# Test accuarcy: 84.99
# Test average loss: 0.0037296973705291748
# Model Saved!
#
# [ Train epoch: 67 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19669286906719208
#
# Current batch: 128
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.2495882213115692
#
# Current batch: 256
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.17965936660766602
#
# Current batch: 384
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3201320767402649
#
# Total benign train accuarcy: 90.564
# Total benign train loss: 105.45041796565056
#
# [ Test epoch: 67 ]
#
# Test accuarcy: 85.72
# Test average loss: 0.003528877344727516
# Model Saved!
#
# [ Train epoch: 68 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3052576184272766
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3098101019859314
#
# Current batch: 256
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2528306543827057
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.29152798652648926
#
# Total benign train accuarcy: 90.522
# Total benign train loss: 105.63257421553135
#
# [ Test epoch: 68 ]
#
# Test accuarcy: 84.22
# Test average loss: 0.0038190002620220186
# Model Saved!
#
# [ Train epoch: 69 ]
#
# Current batch: 0
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.28455740213394165
#
# Current batch: 128
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.24233576655387878
#
# Current batch: 256
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2785797715187073
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3422624170780182
#
# Total benign train accuarcy: 90.664
# Total benign train loss: 104.2255162075162
#
# [ Test epoch: 69 ]
#
# Test accuarcy: 85.96
# Test average loss: 0.003479925325512886
# Model Saved!
#
# [ Train epoch: 70 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2925039529800415
#
# Current batch: 128
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2824229598045349
#
# Current batch: 256
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.2877805829048157
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.34350964426994324
#
# Total benign train accuarcy: 90.586
# Total benign train loss: 105.20281516760588
#
# [ Test epoch: 70 ]
#
# Test accuarcy: 83.82
# Test average loss: 0.0038600176841020583
# Model Saved!
#
# [ Train epoch: 71 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.21955153346061707
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.11871938407421112
#
# Current batch: 256
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.2271796017885208
#
# Current batch: 384
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.3033298850059509
#
# Total benign train accuarcy: 90.484
# Total benign train loss: 105.04080660641193
#
# [ Test epoch: 71 ]
#
# Test accuarcy: 85.18
# Test average loss: 0.003507257513701916
# Model Saved!
#
# [ Train epoch: 72 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.36112502217292786
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.24220867455005646
#
# Current batch: 256
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.18553441762924194
#
# Current batch: 384
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.24126091599464417
#
# Total benign train accuarcy: 90.452
# Total benign train loss: 106.11280144751072
#
# [ Test epoch: 72 ]
#
# Test accuarcy: 84.14
# Test average loss: 0.0037998442351818086
# Model Saved!
#
# [ Train epoch: 73 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2593906819820404
#
# Current batch: 128
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.21550112962722778
#
# Current batch: 256
# Current benign train accuracy: 0.9375
# Current benign train loss: 0.12214229255914688
#
# Current batch: 384
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3953109085559845
#
# Total benign train accuarcy: 90.72
# Total benign train loss: 102.21443673968315
#
# [ Test epoch: 73 ]
#
# Test accuarcy: 84.69
# Test average loss: 0.0038107496917247773
# Model Saved!
#
# [ Train epoch: 74 ]
#
# Current batch: 0
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.22319243848323822
#
# Current batch: 128
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.20770052075386047
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.28218188881874084
#
# Current batch: 384
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2823742926120758
#
# Total benign train accuarcy: 90.938
# Total benign train loss: 102.11694793403149
#
# [ Test epoch: 74 ]
#
# Test accuarcy: 85.27
# Test average loss: 0.0034965691447257996
# Model Saved!
#
# [ Train epoch: 75 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.3196636140346527
#
# Current batch: 128
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.22603414952754974
#
# Current batch: 256
# Current benign train accuracy: 0.875
# Current benign train loss: 0.3484093248844147
#
# Current batch: 384
# Current benign train accuracy: 0.9296875
# Current benign train loss: 0.19507089257240295
#
# Total benign train accuarcy: 90.782
# Total benign train loss: 103.58723668754101
#
# [ Test epoch: 75 ]
#
# Test accuarcy: 86.11
# Test average loss: 0.003391095355898142
# Model Saved!
#
# [ Train epoch: 76 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.2632916569709778
#
# Current batch: 128
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.2877858281135559
#
# Current batch: 256
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.23518501222133636
#
# Current batch: 384
# Current benign train accuracy: 0.90625
# Current benign train loss: 0.251979798078537
#
# Total benign train accuarcy: 90.694
# Total benign train loss: 102.8062166646123
#
# [ Test epoch: 76 ]
#
# Test accuarcy: 85.12
# Test average loss: 0.003491050861775875
# Model Saved!
#
# [ Train epoch: 77 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.39397260546684265
#
# Current batch: 128
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.23519888520240784
#
# ...
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04633269086480141
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06290044635534286
#
# Total benign train accuarcy: 98.044
# Total benign train loss: 23.761523842811584
#
# [ Test epoch: 134 ]
#
# Test accuarcy: 90.35
# Test average loss: 0.002680032503604889
# Model Saved!
#
# [ Train epoch: 135 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06093231216073036
#
# Current batch: 128
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06491474062204361
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05278685316443443
#
# Current batch: 384
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08812524378299713
#
# Total benign train accuarcy: 98.072
# Total benign train loss: 23.080729991197586
#
# [ Test epoch: 135 ]
#
# Test accuarcy: 90.51
# Test average loss: 0.0026522979460656643
# Model Saved!
#
# [ Train epoch: 136 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08667813241481781
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05970253422856331
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04510091617703438
#
# Current batch: 384
# Current benign train accuracy: 1.0
# Current benign train loss: 0.026108695194125175
#
# Total benign train accuarcy: 98.216
# Total benign train loss: 21.745026101358235
#
# [ Test epoch: 136 ]
#
# Test accuarcy: 90.2
# Test average loss: 0.002703187520802021
# Model Saved!
#
# [ Train epoch: 137 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.04592090845108032
#
# Current batch: 128
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05990160256624222
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07730546593666077
#
# Current batch: 384
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.11237296462059021
#
# Total benign train accuarcy: 98.168
# Total benign train loss: 22.405077444389462
#
# [ Test epoch: 137 ]
#
# Test accuarcy: 90.47
# Test average loss: 0.0026301953837275507
# Model Saved!
#
# [ Train epoch: 138 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.045513398945331573
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.07082799077033997
#
# Current batch: 256
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.06755389273166656
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09980027377605438
#
# Total benign train accuarcy: 98.102
# Total benign train loss: 22.3557918202132
#
# [ Test epoch: 138 ]
#
# Test accuarcy: 90.38
# Test average loss: 0.00278317598849535
# Model Saved!
#
# [ Train epoch: 139 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06973027437925339
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05078534781932831
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05448548495769501
#
# Current batch: 384
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.08114907145500183
#
# Total benign train accuarcy: 98.27
# Total benign train loss: 21.697163114324212
#
# [ Test epoch: 139 ]
#
# Test accuarcy: 90.47
# Test average loss: 0.0026435427904129027
# Model Saved!
#
# [ Train epoch: 140 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9453125
# Current benign train loss: 0.08880773186683655
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06546677649021149
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0496147945523262
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04943891987204552
#
# Total benign train accuarcy: 98.12
# Total benign train loss: 21.736849936656654
#
# [ Test epoch: 140 ]
#
# Test accuarcy: 90.49
# Test average loss: 0.002625454182177782
# Model Saved!
#
# [ Train epoch: 141 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06860145926475525
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.053445667028427124
#
# Current batch: 256
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.14363904297351837
#
# Current batch: 384
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.038836520165205
#
# Total benign train accuarcy: 98.048
# Total benign train loss: 22.853792865760624
#
# [ Test epoch: 141 ]
#
# Test accuarcy: 90.22
# Test average loss: 0.0026436647832393644
# Model Saved!
#
# [ Train epoch: 142 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.054039835929870605
#
# Current batch: 128
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04096221923828125
#
# Current batch: 256
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.08122479915618896
#
# Current batch: 384
# Current benign train accuracy: 1.0
# Current benign train loss: 0.02151951938867569
#
# Total benign train accuarcy: 98.086
# Total benign train loss: 22.57965653948486
#
# [ Test epoch: 142 ]
#
# Test accuarcy: 90.36
# Test average loss: 0.0027662815302610397
# Model Saved!
#
# [ Train epoch: 143 ]
#
# Current batch: 0
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06668791174888611
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.057715099304914474
#
# Current batch: 256
# Current benign train accuracy: 1.0
# Current benign train loss: 0.031016170978546143
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.026335334405303
#
# Total benign train accuarcy: 98.214
# Total benign train loss: 21.456122886389494
#
# [ Test epoch: 143 ]
#
# Test accuarcy: 90.42
# Test average loss: 0.0026347495816648006
# Model Saved!
#
# [ Train epoch: 144 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.028424542397260666
#
# Current batch: 128
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03893858194351196
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.048627935349941254
#
# Current batch: 384
# Current benign train accuracy: 1.0
# Current benign train loss: 0.016098741441965103
#
# Total benign train accuarcy: 98.216
# Total benign train loss: 21.66909372806549
#
# [ Test epoch: 144 ]
#
# Test accuarcy: 90.45
# Test average loss: 0.002694559232890606
# Model Saved!
#
# [ Train epoch: 145 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.051231857389211655
#
# Current batch: 128
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03768743947148323
#
# Current batch: 256
# Current benign train accuracy: 1.0
# Current benign train loss: 0.042437005788087845
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.08879577368497849
#
# Total benign train accuarcy: 98.212
# Total benign train loss: 21.61727427970618
#
# [ Test epoch: 145 ]
#
# Test accuarcy: 90.27
# Test average loss: 0.002627815155684948
# Model Saved!
#
# [ Train epoch: 146 ]
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07531876862049103
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.06258290261030197
#
# Current batch: 256
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.0790526270866394
#
# Current batch: 384
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04508253559470177
#
# Total benign train accuarcy: 98.204
# Total benign train loss: 22.076639361679554
#
# [ Test epoch: 146 ]
#
# Test accuarcy: 90.3
# Test average loss: 0.0027264172554016114
# Model Saved!
#
# [ Train epoch: 147 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03934174031019211
#
# Current batch: 128
# Current benign train accuracy: 0.953125
# Current benign train loss: 0.09434585273265839
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.039439607411623
#
# Current batch: 384
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05074981227517128
#
# Total benign train accuarcy: 98.226
# Total benign train loss: 21.677318167872727
#
# [ Test epoch: 147 ]
#
# Test accuarcy: 90.48
# Test average loss: 0.002690793289244175
# Model Saved!
#
# [ Train epoch: 148 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.050633225589990616
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.05530574917793274
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04338084161281586
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.025987224653363228
#
# Total benign train accuarcy: 98.188
# Total benign train loss: 21.743389674462378
#
# [ Test epoch: 148 ]
#
# Test accuarcy: 90.35
# Test average loss: 0.002702950681000948
# Model Saved!
#
# [ Train epoch: 149 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04275238886475563
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04338427260518074
#
# Current batch: 256
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06086760014295578
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.042960282415151596
#
# Total benign train accuarcy: 98.234
# Total benign train loss: 21.742222228087485
#
# [ Test epoch: 149 ]
#
# Test accuarcy: 90.31
# Test average loss: 0.0027821554705500604
# Model Saved!
#
# [ Train epoch: 150 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.037382666021585464
#
# Current batch: 128
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.0762166976928711
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04597983509302139
#
# Current batch: 384
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.06723427027463913
#
# Total benign train accuarcy: 98.15
# Total benign train loss: 22.132121320813894
#
# [ Test epoch: 150 ]
#
# Test accuarcy: 90.13
# Test average loss: 0.0026850180700421335
# Model Saved!
#
# [ Train epoch: 151 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.036904435604810715
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.09954029321670532
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05064707249403
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05212157964706421
#
# Total benign train accuarcy: 98.296
# Total benign train loss: 20.993772376328707
#
# [ Test epoch: 151 ]
#
# Test accuarcy: 90.33
# Test average loss: 0.002751070237159729
# Model Saved!
#
# [ Train epoch: 152 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.024912910535931587
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.031073125079274178
#
# Current batch: 256
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.08314813673496246
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.02868272364139557
#
# Total benign train accuarcy: 98.158
# Total benign train loss: 21.798727797344327
#
# [ Test epoch: 152 ]
#
# Test accuarcy: 90.48
# Test average loss: 0.002666863592714071
# Model Saved!
#
# [ Train epoch: 153 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07330656796693802
#
# Current batch: 128
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03544988855719566
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05335036665201187
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03925548121333122
#
# Total benign train accuarcy: 98.18
# Total benign train loss: 21.8473378457129
#
# [ Test epoch: 153 ]
#
# Test accuarcy: 90.37
# Test average loss: 0.002715152345597744
# Model Saved!
#
# [ Train epoch: 154 ]
#
# Current batch: 0
# Current benign train accuracy: 1.0
# Current benign train loss: 0.0313400998711586
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04205477237701416
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04684382677078247
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07409936189651489
#
# Total benign train accuarcy: 98.172
# Total benign train loss: 21.73970620241016
#
# [ Test epoch: 154 ]
#
# Test accuarcy: 90.0
# Test average loss: 0.002830457803606987
# Model Saved!
#
# [ Train epoch: 155 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.030459899455308914
#
# Current batch: 128
# Current benign train accuracy: 0.96875
# Current benign train loss: 0.055021632462739944
#
# Current batch: 256
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.04565338417887688
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.05293284356594086
#
# Total benign train accuarcy: 98.274
# Total benign train loss: 21.076983698643744
#
# [ Test epoch: 155 ]
#
# Test accuarcy: 90.25
# Test average loss: 0.00266700953245163
# Model Saved!
#
# [ Train epoch: 156 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.04139852151274681
#
# Current batch: 128
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.041628651320934296
#
# Current batch: 256
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.05252693220973015
#
# Current batch: 384
# Current benign train accuracy: 0.9609375
# Current benign train loss: 0.07697218656539917
#
# Total benign train accuarcy: 98.19
# Total benign train loss: 21.31916621234268
#
# [ Test epoch: 156 ]
#
# Test accuarcy: 90.52
# Test average loss: 0.002635503850877285
# Model Saved!
#
# [ Train epoch: 157 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.045869383960962296
#
# Current batch: 128
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.049904532730579376
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04493265599012375
#
# Current batch: 384
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.03244475647807121
#
# Total benign train accuarcy: 98.326
# Total benign train loss: 20.145482819527388
#
# [ Test epoch: 157 ]
#
# Test accuarcy: 90.54
# Test average loss: 0.002615033794939518
# Model Saved!
#
# [ Train epoch: 158 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9921875
# Current benign train loss: 0.041206300258636475
#
# Current batch: 128
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.05573870986700058
#
# Current batch: 256
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.03401121869683266
#
# Current batch: 384
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.0472983717918396
#
# Total benign train accuarcy: 98.28
# Total benign train loss: 21.147740829735994
#
# [ Test epoch: 158 ]
#
# Test accuarcy: 90.29
# Test average loss: 0.0027216781251132487
# Model Saved!
#
# [ Train epoch: 159 ]
#
# Current batch: 0
# Current benign train accuracy: 0.984375
# Current benign train loss: 0.04710066691040993
# Current batch: 128
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07056177407503128
#
# Current batch: 256
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.07591348141431808
#
# Current batch: 384
# Current benign train accuracy: 0.9765625
# Current benign train loss: 0.09283935278654099
#
# Total benign train accuarcy: 98.18
# Total benign train loss: 21.89087953325361
#
# [ Test epoch: 159 ]
#
# Test accuarcy: 90.52
# Test average loss: 0.002663247208297253
# Model Saved!
