# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import math
import os

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')

print(device)
# Out:
# cuda

# %%
transform = transforms.Compose([
    transforms.Resize((28,28)),
    transforms.ToTensor()
])

train_dataset = datasets.MNIST('mnist',train=True, download=True, transform=transform)
test_dataset = datasets.MNIST('mnist',train=False, transform=transform)
train_loader = DataLoader(train_dataset, num_workers=2,shuffle=True,batch_size=32)
test_loader = DataLoader(test_dataset, num_workers=2,shuffle=True,batch_size=32)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
class SoftMaxNet(nn.Module):
    def __init__(self):
        super(SoftMaxNet, self).__init__()
        self.conv_layer = nn.Sequential(
            nn.Conv2d(1, 256, 5),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(256, 256, 3),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(256, 3, 5),
            nn.AdaptiveAvgPool2d(1))
        self.classifier = nn.Linear(3, 10)
        
    def forward(self, x):
        x = self.conv_layer(x)
        x = x.view(x.shape[0], 3)
        x = self.classifier(x)
        return x
    
    def get_feature(self, x):
        with torch.no_grad():
            x = self.conv_layer(x)
            x = x.view(x.shape[0], 3)
            x = F.normalize(x)
            return x

# %%
softmax_net = SoftMaxNet().to(device)
learning_rate = 0.1
criterion = nn.CrossEntropyLoss() # softmax 이미 포함
optimizer = optim.SGD(softmax_net.parameters(), lr=learning_rate)

# %%
def train(net,epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()

        outputs = net(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, prediction = outputs.max(1)

        total += labels.size(0)
        correct += prediction.eq(labels).sum().item()

        if batch_idx % 500 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current train accuracy:', str(prediction.eq(labels).sum().item() / labels.size(0)))
            print('Current train average loss:', loss.item() / 100)


    print('\nTrain accuarcy:', 100. * correct / total)
    print('Train average loss:', train_loss / total)


def test(net,epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (images, labels) in enumerate(test_loader):
        images = images.to(device)
        labels = labels.to(device)
        total += labels.size(0)

        outputs = net(images)
        loss += criterion(outputs, labels).item()

        _, prediction = outputs.max(1)
        correct += prediction.eq(labels).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

# %%
for epoch in range(0,15) :
    train(softmax_net,epoch)
# Out:
# [ Train epoch: 0 ]
#
# Current batch: 0
# Current train accuracy: 0.125
# Current train average loss: 0.02384641408920288
#
# Current batch: 500
# Current train accuracy: 0.96875
# Current train average loss: 0.0014779968559741974
#
# Current batch: 1000
# Current train accuracy: 0.96875
# Current train average loss: 0.0004834190756082535
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.002378498762845993
#
# Train accuarcy: 90.4
# Train average loss: 0.009210561724596967
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current train accuracy: 0.96875
# Current train average loss: 0.000611896887421608
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.0005799781903624534
#
# Current batch: 1000
# Current train accuracy: 0.96875
# Current train average loss: 0.0009435483813285828
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 0.0004047057032585144
#
# Train accuarcy: 97.15
# Train average loss: 0.0030140302983500686
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 0.00023028545081615448
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.00016682399436831474
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 0.0002076704241335392
#
# Current batch: 1500
# Current train accuracy: 0.9375
# Current train average loss: 0.0037848827242851256
#
# Train accuarcy: 97.91833333333334
# Train average loss: 0.0021744046862625208
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 0.0002955339662730694
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.00022962531074881553
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 0.00019973697140812874
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.0003475816920399666
#
# Train accuarcy: 98.39166666666667
# Train average loss: 0.0017041186463373984
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current train accuracy: 0.96875
# Current train average loss: 0.0005268612504005432
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.0002039155550301075
#
# Current batch: 1000
# Current train accuracy: 0.96875
# Current train average loss: 0.0004342532530426979
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.00044694315642118454
#
# Train accuarcy: 98.635
# Train average loss: 0.001386054039906594
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 0.00030438492074608803
#
# Current batch: 500
# Current train accuracy: 0.96875
# Current train average loss: 0.002523561418056488
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 0.00027909133583307264
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.0004631252214312553
#
# Train accuarcy: 98.90833333333333
# Train average loss: 0.0011426306435246565
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 3.2551458571106197e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 2.706285333260894e-05
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 0.0001941997930407524
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 0.00011877083219587803
#
# Train accuarcy: 99.10333333333334
# Train average loss: 0.0009121759205782534
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 0.00022257117554545404
#
# Current batch: 500
# Current train accuracy: 0.96875
# Current train average loss: 0.0019975925981998446
#
# Current batch: 1000
# Current train accuracy: 0.96875
# Current train average loss: 0.00046039529144763946
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.00027972765266895297
#
# Train accuarcy: 99.31333333333333
# Train average loss: 0.0007070681906707856
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 1.7885400447994472e-05
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.00014708477072417737
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 1.8331102910451592e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 0.00010348509065806866
#
# Train accuarcy: 99.41833333333334
# Train average loss: 0.0005839711990191063
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 5.6032842257991434e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 7.492335978895426e-05
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 7.744058966636658e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 8.918989449739456e-05
#
# Train accuarcy: 99.53666666666666
# Train average loss: 0.00044971113305210416
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 9.752013720571995e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 0.0005679313093423843
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 4.8841314855962995e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 4.042111337184906e-05
#
# Train accuarcy: 99.66666666666667
# Train average loss: 0.0003529740627178929
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 3.3741220249794423e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 5.1871179603040216e-05
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 1.6013193817343563e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 2.532359794713557e-06
#
# Train accuarcy: 99.705
# Train average loss: 0.00030381012143409407
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 2.707742096390575e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 9.451246296521276e-07
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 0.00014113076962530614
#
# Current batch: 1500
# Current train accuracy: 0.96875
# Current train average loss: 0.0006445913761854171
#
# Train accuarcy: 99.78333333333333
# Train average loss: 0.00022710101806928075
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 1.5476853877771646e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 1.6038493486121295e-05
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 2.2005336359143256e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 6.617431063205004e-06
#
# Train accuarcy: 99.91166666666666
# Train average loss: 0.00011665039343110569
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current train accuracy: 1.0
# Current train average loss: 7.758751162327825e-06
#
# Current batch: 500
# Current train accuracy: 1.0
# Current train average loss: 1.8459824786987157e-07
#
# Current batch: 1000
# Current train accuracy: 1.0
# Current train average loss: 8.458839147351682e-06
#
# Current batch: 1500
# Current train accuracy: 1.0
# Current train average loss: 2.48808937612921e-06
#
# Train accuarcy: 99.94333333333333
# Train average loss: 8.231223346344525e-05

# %%
from tqdm.notebook import tqdm

# helper method to extract all embedings from a data loader
def get_embs(model, dl):
    embs = []
    ys = []
    for bx,by in tqdm(dl):
        bx = bx.cuda()
        by = by.cuda()
        with torch.no_grad():
            embs.append(model.get_feature(bx))
            ys.append(by)
    embs = torch.cat(embs)
    embs = embs / embs.norm(p=2,dim=1)[:,None]
    ys = torch.cat(ys)
    return embs,ys

# helper to plot embeddings in 3D
def plot_embs(embs, ys, ax):
    #ax.axis('off')
    for k in range(10):
        e = embs[ys==k].cpu()
        ax.scatter(e[:,0], e[:,1], e[:,2], s=4, alpha=.2)

# %%
embs_softmax, ys_softmax  = get_embs(softmax_net, test_loader)
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]

# %%
_,(ax1,ax2)=plt.subplots(1,2, figsize=(20,10), subplot_kw={'projection':'3d'})

plot_embs(embs_softmax, ys_softmax, ax2)

plt.show()
